# %%
import pandas as pd
import numpy as np

# %%
df_tracks = pd.read_parquet('../data/processed/df_tracks.parquet', engine="pyarrow")
df_tracks
# Out:
#                                            album_name  \
# 0                       The Times They Are A-Changin'
# 1                           Bringing It All Back Home
# 2        The Best: Loggins & Messina Sittin' In Again
# 3                          The Freewheelin' Bob Dylan
# 4                          The Freewheelin' Bob Dylan
# ...                                               ...
# 2262287                                   Philophobia
# 2262288                     My Kids Salute Our Troops
# 2262289                        Downtown / Archipelago
# 2262290                              Train of Thought
# 2262291                                   Yearling XL
#
#                                     album_uri        artist_name  \
# 0        spotify:album:7DZeLXvr9eTVpyI1OlqtcS          Bob Dylan
# 1        spotify:album:1lPoRKSgZHQAYXxzBsOQ7v          Bob Dylan
# 2        spotify:album:5BWgJaesMjpJWCTU9sgUPf  Loggins & Messina
# 3        spotify:album:0o1uFxZ1VTviqvNaYkTJek          Bob Dylan
# 4        spotify:album:0o1uFxZ1VTviqvNaYkTJek          Bob Dylan
# ...                                       ...                ...
# 2262287  spotify:album:7maGHx2VJGTBPczcWT9JVm         Arab Strap
# 2262288  spotify:album:5HuTwuPKjQKNpmLmmi4Njx    Various Artists
# 2262289  spotify:album:5aauU2AK4iG01BxIchws8Q             Faragó
# 2262290  spotify:album:2MUG8V88S5mazH8n45AKuZ         Crazy Fool
# 2262291  spotify:album:7ohtvyVWbnRzFSdK31anNr       Ace Reporter
#
#                                     artist_uri  duration_ms  \
# 0        spotify:artist:74ASZWbe4lXaubB36ztrGX       277106
# 1        spotify:artist:74ASZWbe4lXaubB36ztrGX       330533
# 2        spotify:artist:7emRV8AluG3d4e5T0DZiK9       254653
# 3        spotify:artist:74ASZWbe4lXaubB36ztrGX       412200
# 4        spotify:artist:74ASZWbe4lXaubB36ztrGX       165426
# ...                                        ...          ...
# 2262287  spotify:artist:6g8Jqb5JMfv92eB2r0awTN       303106
# 2262288  spotify:artist:0LyfQWJT6nXafLPZqxe9Of       314644
# 2262289  spotify:artist:6x3HJm6n40OUW2ZcmttBxQ       297176
# 2262290  spotify:artist:4UrrAgW6WW7UfZ760eyHe7       278973
# 2262291  spotify:artist:1Hv1EPuWXNVIQP4QVad7wH       242720
#
#                             track_name                             track_uri  \
# 0             Boots of Spanish Leather  spotify:track:6QHYEZlm9wyfXfEM1vSu1P
# 1                   Mr. Tambourine Man  spotify:track:3RkQ3UwOyPqpIiIvGVewuU
# 2                         Danny's Song  spotify:track:0ju1jP0cSPJ8tmojYBEI89
# 3           A Hard Rain's A-Gonna Fall  spotify:track:7ny2ATvjtKszCpLpfsGnVQ
# 4                  Blowin' In the Wind  spotify:track:18GiV1BaXzPVYpp9rmOg0E
# ...                                ...                                   ...
# 2262287              My Favourite Muse  spotify:track:2wBZrBqWQ4eIhShITfUJ4c
# 2262288  The Stars and Stripes Forever  spotify:track:2t7fotSpsiWHpSTySbSNZg
# 2262289                         Killer  spotify:track:0EW4RltERtn276lOi0DXQj
# 2262290                     Robin Hood  spotify:track:5RiCId3jJs8D9g6Fv4A1Su
# 2262291                      Guilttrip  spotify:track:6JVPoZpUZZJSQ39vsXhmcD
#
#              tid
# 0              0
# 1              1
# 2              2
# 3              3
# 4              4
# ...          ...
# 2262287  2262287
# 2262288  2262288
# 2262289  2262289
# 2262290  2262290
# 2262291  2262291
#
# [2262292 rows x 8 columns]

# %%
df_playlist = pd.read_parquet('../data/processed/df_playlists.parquet', engine="pyarrow")
df_playlist
# Out:
#              pid     tid  pos
# 0         549000       0    0
# 1         549000       1    1
# 2         549000       2    2
# 3         549000       3    3
# 4         549000       4    4
# ...          ...     ...  ...
# 66346423  302999  399233   15
# 66346424  302999   11291   16
# 66346425  302999   93795   17
# 66346426  302999  133087   18
# 66346427  302999  133088   19
#
# [66346428 rows x 3 columns]

# %%
df_playlist_test = pd.read_parquet('../data/processed/df_playlists_test.parquet', engine="pyarrow")
df_playlist_test
# Out:
#             pid      tid  pos
# 0       1000000    26539    0
# 1       1000000    10214    1
# 2       1000000    12544    2
# 3       1000000     3188    3
# 4       1000000     3187    4
# ...         ...      ...  ...
# 280995  1006767  1016431    0
# 280996  1006771    13570    0
# 280997  1006773   120591    0
# 280998  1006775    15035    0
# 280999  1006778    20435    0
#
# [281000 rows x 3 columns]

# %%
df_playlist_info = pd.read_parquet('../data/processed/df_playlists_info.parquet', engine="pyarrow")
df_playlist_info
# Out:
#         collaborative  duration_ms  modified_at             name  num_albums  \
# 0               False     18425368   1454803200        Bob Dylan          65
# 1               False     15224873   1419552000       ON THE RUN          30
# 2               False     32723071   1435708800           Biking         117
# 3               False      8439352   1505001600           August          32
# 4               False      3804816   1459555200          run mix          15
# ...               ...          ...          ...              ...         ...
# 999995          False     22126318   1465344000  Hip Hop and R&B          65
# 999996          False      4725029   1464393600              MAY          19
# 999997          False     30219710   1455840000        Road Trip         106
# 999998          False     50603668   1503705600  Guilty Pleasure         209
# 999999          False      4689701   1482019200         ❤️❤️❤️❤️          15
#
#         num_artists  num_edits  num_followers  num_tracks     pid
# 0                39         28              1          75  549000
# 1                 5          4              1          61  549001
# 2                72         12              1         144  549002
# 3                33         20              1          38  549003
# 4                12          3              1          16  549004
# ...             ...        ...            ...         ...     ...
# 999995           34          5              1          83  302995
# 999996           18          6              2          21  302996
# 999997           71          2              1         137  302997
# 999998          185         57              2         223  302998
# 999999            9          2              1          20  302999
#
# [1000000 rows x 10 columns]

# %%
df_playlist_test_info = pd.read_parquet('../data/processed/df_playlists_test_info.parquet', engine="pyarrow")
df_playlist_test_info
# Out:
#                   name  num_holdouts  num_samples  num_tracks      pid
# 0     spanish playlist            11            0          11  1000002
# 1              Groovin            48            0          48  1000003
# 2               uplift            40            0          40  1000004
# 3                 WUBZ            27            0          27  1000006
# 4                  new            41            0          41  1000007
# ...                ...           ...          ...         ...      ...
# 9995     Playlist 2015            20            1          21  1006767
# 9996           Workout            24            1          25  1006771
# 9997             Girlz            16            1          17  1006773
# 9998    let's get lost            35            1          36  1006775
# 9999              Mama            28            1          29  1006778
#
# [10000 rows x 5 columns]

# %% [markdown]
# ### Total number of playlist

# %%
df_playlist_test['pid'].nunique()
# Out:
# 9000
