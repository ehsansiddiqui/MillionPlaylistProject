# %%
from pyspark.sql import SparkSession
from pyspark.sql.types import StructType, StructField, StringType, IntegerType, ArrayType, LongType

def load_and_process_data(filepath, n_samples=None):
    """
    Load and preprocess the Million Playlist Dataset using Spark with explicit schema.

    Args:
        filepath (str): Path to the JSON file.
        n_samples (int, optional): Number of playlists to sample. Load all if None.

    Returns:
        Spark DataFrame: A preprocessed DataFrame.
    """
    # Initialize SparkSession
    spark = SparkSession.builder \
        .appName("Million Playlist Dataset Processing") \
        .getOrCreate()

    # Define the schema explicitly
    track_schema = StructType([
        StructField("pos", IntegerType(), True),
        StructField("artist_name", StringType(), True),
        StructField("track_uri", StringType(), True),
        StructField("artist_uri", StringType(), True),
        StructField("track_name", StringType(), True),
        StructField("album_uri", StringType(), True),
        StructField("duration_ms", LongType(), True),
        StructField("album_name", StringType(), True)
    ])

    playlist_schema = StructType([
        StructField("name", StringType(), True),
        StructField("collaborative", StringType(), True),
        StructField("pid", IntegerType(), True),
        StructField("modified_at", LongType(), True),
        StructField("num_tracks", IntegerType(), True),
        StructField("num_albums", IntegerType(), True),
        StructField("num_followers", IntegerType(), True),
        StructField("tracks", ArrayType(track_schema), True),
        StructField("num_edits", IntegerType(), True),
        StructField("duration_ms", LongType(), True),
        StructField("num_artists", IntegerType(), True)
    ])

    schema = StructType([
        StructField("info", StructType([
            StructField("generated_on", StringType(), True),
            StructField("slice", StringType(), True),
            StructField("version", StringType(), True)
        ]), True),
        StructField("playlists", ArrayType(playlist_schema), True)
    ])

    # Load the JSON file with the schema
    df = spark.read.schema(schema).option("multiline", "true").json(filepath)

    # Flatten the playlists structure
    playlists_df = df.select(explode(col("playlists")).alias("playlist"))

    # Extract playlist-level metadata
    playlists_metadata = playlists_df.select(
        col("playlist.name").alias("playlist_name"),
        col("playlist.pid").alias("playlist_id"),
        col("playlist.num_tracks"),
        col("playlist.num_albums"),
        col("playlist.num_artists"),
        col("playlist.duration_ms").alias("playlist_duration"),
        col("playlist.num_followers"),
        col("playlist.modified_at"),
        explode(col("playlist.tracks")).alias("track")
    )

    # Extract track-level details
    tracks_df = playlists_metadata.select(
        col("playlist_name"),
        col("playlist_id"),
        col("num_tracks"),
        col("num_albums"),
        col("num_artists"),
        col("playlist_duration"),
        col("num_followers"),
        col("modified_at"),
        col("track.pos").alias("track_position"),
        col("track.artist_name").alias("artist_name"),
        col("track.track_uri").alias("track_uri"),
        col("track.artist_uri").alias("artist_uri"),
        col("track.track_name").alias("track_name"),
        col("track.album_uri").alias("album_uri"),
        col("track.duration_ms").alias("track_duration"),
        col("track.album_name").alias("album_name")
    )

    # Sample the data if n_samples is specified
    if n_samples:
        tracks_df = tracks_df.limit(n_samples)

    return tracks_df


if __name__ == "__main__":
    input_path = "mpd.slice.0-999.json"  # Replace with your JSON file path
    output_path = "output/processed_playlists"

    # Load and process the data
    tracks_df = load_and_process_data(input_path, n_samples=100)

    # Show a preview of the data
    tracks_df.show(5, truncate=False)
# Out:
# +-------------+-----------+----------+----------+-----------+-----------------+-------------+-----------+--------------+-----------------+------------------------------------+-------------------------------------+------------------------------------------+------------------------------------+--------------+--------------------------------------------+
# |playlist_name|playlist_id|num_tracks|num_albums|num_artists|playlist_duration|num_followers|modified_at|track_position|artist_name      |track_uri                           |artist_uri                           |track_name                                |album_uri                           |track_duration|album_name                                  |
# +-------------+-----------+----------+----------+-----------+-----------------+-------------+-----------+--------------+-----------------+------------------------------------+-------------------------------------+------------------------------------------+------------------------------------+--------------+--------------------------------------------+
# |Throwbacks   |0          |52        |47        |37         |11532414         |1            |1493424000 |0             |Missy Elliott    |spotify:track:0UaMYEvWZi0ZqiDOoHU3YI|spotify:artist:2wIVse2owClT7go1WT98tk|Lose Control (feat. Ciara & Fat Man Scoop)|spotify:album:6vV5UrXcfyQD1wu4Qo2I9K|226863        |The Cookbook                                |
# |Throwbacks   |0          |52        |47        |37         |11532414         |1            |1493424000 |1             |Britney Spears   |spotify:track:6I9VzXrHxO9rA9A5euc8Ak|spotify:artist:26dSoYclwsYLMAKD3tpOr4|Toxic                                     |spotify:album:0z7pVBGOD7HCIB7S8eLkLI|198800        |In The Zone                                 |
# |Throwbacks   |0          |52        |47        |37         |11532414         |1            |1493424000 |2             |Beyoncé          |spotify:track:0WqIKmW4BTrj3eJFmnCKMv|spotify:artist:6vWDO969PvNqNYHIOW5v0m|Crazy In Love                             |spotify:album:25hVFAxTlDvXbx2X2QkUkE|235933        |Dangerously In Love (Alben für die Ewigkeit)|
# |Throwbacks   |0          |52        |47        |37         |11532414         |1            |1493424000 |3             |Justin Timberlake|spotify:track:1AWQoqb9bSvzTjaLralEkT|spotify:artist:31TPClRtHm23RisEBtV3X7|Rock Your Body                            |spotify:album:6QPkyl04rXwTGlGlcYaRoW|267266        |Justified                                   |
# |Throwbacks   |0          |52        |47        |37         |11532414         |1            |1493424000 |4             |Shaggy           |spotify:track:1lzr43nnXAijIGYnCT8M8H|spotify:artist:5EvFsr3kj42KNv97ZEnqij|It Wasn't Me                              |spotify:album:6NmFmPX56pcLBOFMhIiKvF|227600        |Hot Shot                                    |
# +-------------+-----------+----------+----------+-----------+-----------------+-------------+-----------+--------------+-----------------+------------------------------------+-------------------------------------+------------------------------------------+------------------------------------+--------------+--------------------------------------------+
# only showing top 5 rows

# %%
def save_data(df, output_path):
    """
    Save the preprocessed DataFrame to a Parquet file.

    Args:
        df (DataFrame): The Spark DataFrame to save.
        output_path (str): The path to save the Parquet file.
    """
    df.write.parquet(output_path, mode="overwrite")
    print(f"Data saved to {output_path}")

# %%
  # Save the preprocessed data
save_data(tracks_df, output_path)
# Out:
# Data saved to output/processed_playlists

# %%
spark = SparkSession.builder \
            .appName("Million Playlist Dataset Processing") \
            .getOrCreate()
# Out:
# 24/12/05 01:40:42 WARN SparkSession: Using an existing Spark session; only runtime SQL configurations will take effect.

# %%
simple_schema = StructType([
            StructField("name", StringType(), True),
            StructField("age", StringType(), True),
            StructField("car", IntegerType(), True),
        ])

# %%
    # Load the JSON file with the schema
df = spark.read.schema(simple_schema).json("simple.json")
df
# Out:
# DataFrame[name: string, age: string, car: int]

# %%
df.show()
# Out:
# +----+---+----+
# |name|age| car|
# +----+---+----+
# |John| 30|NULL|
# +----+---+----+

# %%
# Read the file without a schema
df1 = spark.read.option("multiline", "true").json("sample.json")

# Show the schema
df1.printSchema()
# Out:
# root
#  |-- info: struct (nullable = true)
#  |    |-- generated_on: string (nullable = true)
#  |    |-- slice: string (nullable = true)
#  |    |-- version: string (nullable = true)
#  |-- playlists: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- collaborative: string (nullable = true)
#  |    |    |-- duration_ms: long (nullable = true)
#  |    |    |-- modified_at: long (nullable = true)
#  |    |    |-- name: string (nullable = true)
#  |    |    |-- num_albums: long (nullable = true)
#  |    |    |-- num_artists: long (nullable = true)
#  |    |    |-- num_edits: long (nullable = true)
#  |    |    |-- num_followers: long (nullable = true)
#  |    |    |-- num_tracks: long (nullable = true)
#  |    |    |-- pid: long (nullable = true)
#  |    |    |-- tracks: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- album_name: string (nullable = true)
#  |    |    |    |    |-- album_uri: string (nullable = true)
#  |    |    |    |    |-- artist_name: string (nullable = true)
#  |    |    |    |    |-- artist_uri: string (nullable = true)
#  |    |    |    |    |-- duration_ms: long (nullable = true)
#  |    |    |    |    |-- pos: long (nullable = true)
#  |    |    |    |    |-- track_name: string (nullable = true)
#  |    |    |    |    |-- track_uri: string (nullable = true)

# %%
# Show the DataFrame
df1.show(truncate=False)
# Out:
# +---------------------------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |info                                   |playlists                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             |
# +---------------------------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |{2017-12-03 08:41:42.057563, 0-999, v1}|[{false, 11532414, 1493424000, Throwbacks, 47, 37, 6, 1, 52, 0, [{The Cookbook, spotify:album:6vV5UrXcfyQD1wu4Qo2I9K, Missy Elliott, spotify:artist:2wIVse2owClT7go1WT98tk, 226863, 0, Lose Control (feat. Ciara & Fat Man Scoop), spotify:track:0UaMYEvWZi0ZqiDOoHU3YI}, {In The Zone, spotify:album:0z7pVBGOD7HCIB7S8eLkLI, Britney Spears, spotify:artist:26dSoYclwsYLMAKD3tpOr4, 198800, 1, Toxic, spotify:track:6I9VzXrHxO9rA9A5euc8Ak}]}, {false, 11656470, 1506556800, Awesome Playlist, 23, 21, 5, 1, 39, 1, [{Eye Of The Tiger, spotify:album:4PT9VulQaQP6XR1xBI2x1W, Survivor, spotify:artist:26bcq2nyj5GB7uRr558iQg, 243773, 0, Eye of the Tiger, spotify:track:2HHtWyy5CgaQbC7XSoOb0e}, {Versus Hollywood, spotify:album:3q8vR3PFV8kG1m1Iv8DpKq, Daniel Tidwell, spotify:artist:7zdmbPudNX4SQJXnYIuCTC, 70294, 1, Libera Me From Hell (Tengen Toppa Gurren Lagann), spotify:track:1MYYt7h6amcrauCOoso3Gx}, {Versus Hollywood, spotify:album:3q8vR3PFV8kG1m1Iv8DpKq, Daniel Tidwell, spotify:artist:7zdmbPudNX4SQJXnYIuCTC, 65306, 2, Pokémon Theme, spotify:track:3x2mJ2bjCIU70NrH49CtYR}, {Versus Hollywood, spotify:album:3q8vR3PFV8kG1m1Iv8DpKq, Daniel Tidwell, spotify:artist:7zdmbPudNX4SQJXnYIuCTC, 108532, 3, Concerning Hobbits (The Lord of the Rings), spotify:track:1Pm3fq1SC6lUlNVBGZi3Em}]}]|
# +---------------------------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+

# %%
spark.stop()

# %%
import os
import json

import pandas as pd

# %%
# !mkdir df_data
# Out:
# mkdir: df_data: File exists

# %%
def create_df_data():
    
    path = '../data/raw/data'
    
    playlist_col = ['collaborative', 'duration_ms', 'modified_at', 
                'name', 'num_albums', 'num_artists', 'num_edits',
                'num_followers', 'num_tracks', 'pid']
    tracks_col = ['album_name', 'album_uri', 'artist_name', 'artist_uri', 
                  'duration_ms', 'track_name', 'track_uri'] 
    playlist_test_col = ['name', 'num_holdouts', 'num_samples', 'num_tracks', 'pid']
    
    filenames = os.listdir(path)
    
    data_playlists = []
    data_tracks = []
    playlists = []

    tracks = set()

    for filename in filenames:
        fullpath = os.sep.join((path, filename))
        f = open(fullpath)
        print(fullpath)
        js = f.read()
        f.close()

        mpd_slice = json.loads(js)

        for playlist in mpd_slice['playlists']:
            data_playlists.append([playlist[col] for col in playlist_col])
            for track in playlist['tracks']:
                playlists.append([playlist['pid'], track['track_uri'], track['pos']])
                if track['track_uri'] not in tracks:
                    data_tracks.append([track[col] for col in tracks_col])
                    tracks.add(track['track_uri'])
                    
    f = open('challenge_set.json')
    js = f.read()
    f.close()
    mpd_slice = json.loads(js)

    data_playlists_test = []
    playlists_test = []

    for playlist in mpd_slice['playlists']:
        data_playlists_test.append([playlist.get(col, '') for col in playlist_test_col])
        for track in playlist['tracks']:
            playlists_test.append([playlist['pid'], track['track_uri'], track['pos']])
            if track['track_uri'] not in tracks:
                data_tracks.append([track[col] for col in tracks_col])
                tracks.add(track['track_uri'])
                
    df_playlists_info = pd.DataFrame(data_playlists, columns=playlist_col)
    df_playlists_info['collaborative'] = df_playlists_info['collaborative'].map({'false': False, 'true': True})

    df_tracks = pd.DataFrame(data_tracks, columns=tracks_col)
    df_tracks['tid'] = df_tracks.index

    track_uri2tid = df_tracks.set_index('track_uri').tid

    df_playlists = pd.DataFrame(playlists, columns=['pid', 'tid', 'pos'])
    df_playlists.tid = df_playlists.tid.map(track_uri2tid)

    df_playlists_test_info = pd.DataFrame(data_playlists_test, columns=playlist_test_col)

    df_playlists_test = pd.DataFrame(playlists_test, columns=['pid', 'tid', 'pos'])
    df_playlists_test.tid = df_playlists_test.tid.map(track_uri2tid)

    df_tracks.to_parquet('../data/processed/df_tracks.parquet')
    df_playlists.to_parquet('../data/processed/df_playlists.parquet')
    df_playlists_info.to_parquet('../data/processed/df_playlists_info.parquet')
    df_playlists_test.to_parquet('../data/processed/df_playlists_test.parquet')
    df_playlists_test_info.to_parquet('../data/processed/df_playlists_test_info.parquet')

# %%
create_df_data()
# Out:
# ../data/raw/data/mpd.slice.549000-549999.json
# ../data/raw/data/mpd.slice.613000-613999.json
# ../data/raw/data/mpd.slice.115000-115999.json
# ../data/raw/data/mpd.slice.778000-778999.json
# ../data/raw/data/mpd.slice.290000-290999.json
# ../data/raw/data/mpd.slice.596000-596999.json
# ../data/raw/data/mpd.slice.324000-324999.json
# ../data/raw/data/mpd.slice.422000-422999.json
# ../data/raw/data/mpd.slice.974000-974999.json
# ../data/raw/data/mpd.slice.679000-679999.json
# ../data/raw/data/mpd.slice.7000-7999.json
# ../data/raw/data/mpd.slice.391000-391999.json
# ../data/raw/data/mpd.slice.497000-497999.json
# ../data/raw/data/mpd.slice.225000-225999.json
# ../data/raw/data/mpd.slice.523000-523999.json
# ../data/raw/data/mpd.slice.875000-875999.json
# ../data/raw/data/mpd.slice.448000-448999.json
# ../data/raw/data/mpd.slice.712000-712999.json
# ../data/raw/data/mpd.slice.193000-193999.json
# ../data/raw/data/mpd.slice.38000-38999.json
# ../data/raw/data/mpd.slice.695000-695999.json
# ../data/raw/data/mpd.slice.899000-899999.json
# ../data/raw/data/mpd.slice.721000-721999.json
# ../data/raw/data/mpd.slice.510000-510999.json
# ../data/raw/data/mpd.slice.846000-846999.json
# ../data/raw/data/mpd.slice.216000-216999.json
# ../data/raw/data/mpd.slice.411000-411999.json
# ../data/raw/data/mpd.slice.947000-947999.json
# ../data/raw/data/mpd.slice.317000-317999.json
# ../data/raw/data/mpd.slice.22000-22999.json
# ../data/raw/data/mpd.slice.794000-794999.json
# ../data/raw/data/mpd.slice.126000-126999.json
# ../data/raw/data/mpd.slice.998000-998999.json
# ../data/raw/data/mpd.slice.620000-620999.json
# ../data/raw/data/mpd.slice.3000-3999.json
# ../data/raw/data/mpd.slice.70000-70999.json
# ../data/raw/data/mpd.slice.597000-597999.json
# ../data/raw/data/mpd.slice.291000-291999.json
# ../data/raw/data/mpd.slice.779000-779999.json
# ../data/raw/data/mpd.slice.423000-423999.json
# ../data/raw/data/mpd.slice.975000-975999.json
# ../data/raw/data/mpd.slice.325000-325999.json
# ../data/raw/data/mpd.slice.548000-548999.json
# ../data/raw/data/mpd.slice.114000-114999.json
# ../data/raw/data/mpd.slice.612000-612999.json
# ../data/raw/data/mpd.slice.449000-449999.json
# ../data/raw/data/mpd.slice.713000-713999.json
# ../data/raw/data/mpd.slice.496000-496999.json
# ../data/raw/data/mpd.slice.390000-390999.json
# ../data/raw/data/mpd.slice.678000-678999.json
# ../data/raw/data/mpd.slice.522000-522999.json
# ../data/raw/data/mpd.slice.874000-874999.json
# ../data/raw/data/mpd.slice.224000-224999.json
# ../data/raw/data/mpd.slice.81000-81999.json
# ../data/raw/data/mpd.slice.217000-217999.json
# ../data/raw/data/mpd.slice.511000-511999.json
# ../data/raw/data/mpd.slice.847000-847999.json
# ../data/raw/data/mpd.slice.694000-694999.json
# ../data/raw/data/mpd.slice.192000-192999.json
# ../data/raw/data/mpd.slice.720000-720999.json
# ../data/raw/data/mpd.slice.898000-898999.json
# ../data/raw/data/mpd.slice.54000-54999.json
# ../data/raw/data/mpd.slice.795000-795999.json
# ../data/raw/data/mpd.slice.621000-621999.json
# ../data/raw/data/mpd.slice.999000-999999.json
# ../data/raw/data/mpd.slice.127000-127999.json
# ../data/raw/data/mpd.slice.316000-316999.json
# ../data/raw/data/mpd.slice.410000-410999.json
# ../data/raw/data/mpd.slice.946000-946999.json
# ../data/raw/data/mpd.slice.227000-227999.json
# ../data/raw/data/mpd.slice.84000-84999.json
# ../data/raw/data/mpd.slice.877000-877999.json
# ../data/raw/data/mpd.slice.521000-521999.json
# ../data/raw/data/mpd.slice.393000-393999.json
# ../data/raw/data/mpd.slice.495000-495999.json
# ../data/raw/data/mpd.slice.710000-710999.json
# ../data/raw/data/mpd.slice.611000-611999.json
# ../data/raw/data/mpd.slice.117000-117999.json
# ../data/raw/data/mpd.slice.51000-51999.json
# ../data/raw/data/mpd.slice.326000-326999.json
# ../data/raw/data/mpd.slice.976000-976999.json
# ../data/raw/data/mpd.slice.420000-420999.json
# ../data/raw/data/mpd.slice.292000-292999.json
# ../data/raw/data/mpd.slice.594000-594999.json
# ../data/raw/data/mpd.slice.945000-945999.json
# ../data/raw/data/mpd.slice.413000-413999.json
# ../data/raw/data/mpd.slice.75000-75999.json
# ../data/raw/data/mpd.slice.315000-315999.json
# ../data/raw/data/mpd.slice.749000-749999.json
# ../data/raw/data/mpd.slice.124000-124999.json
# ../data/raw/data/mpd.slice.622000-622999.json
# ../data/raw/data/mpd.slice.578000-578999.json
# ../data/raw/data/mpd.slice.796000-796999.json
# ../data/raw/data/mpd.slice.723000-723999.json
# ../data/raw/data/mpd.slice.191000-191999.json
# ../data/raw/data/mpd.slice.479000-479999.json
# ../data/raw/data/mpd.slice.697000-697999.json
# ../data/raw/data/mpd.slice.844000-844999.json
# ../data/raw/data/mpd.slice.512000-512999.json
# ../data/raw/data/mpd.slice.214000-214999.json
# ../data/raw/data/mpd.slice.648000-648999.json
# ../data/raw/data/mpd.slice.711000-711999.json
# ../data/raw/data/mpd.slice.876000-876999.json
# ../data/raw/data/mpd.slice.520000-520999.json
# ../data/raw/data/mpd.slice.226000-226999.json
# ../data/raw/data/mpd.slice.494000-494999.json
# ../data/raw/data/mpd.slice.392000-392999.json
# ../data/raw/data/mpd.slice.977000-977999.json
# ../data/raw/data/mpd.slice.421000-421999.json
# ../data/raw/data/mpd.slice.327000-327999.json
# ../data/raw/data/mpd.slice.595000-595999.json
# ../data/raw/data/mpd.slice.293000-293999.json
# ../data/raw/data/mpd.slice.116000-116999.json
# ../data/raw/data/mpd.slice.610000-610999.json
# ../data/raw/data/mpd.slice.27000-27999.json
# ../data/raw/data/mpd.slice.6000-6999.json
# ../data/raw/data/mpd.slice.623000-623999.json
# ../data/raw/data/mpd.slice.125000-125999.json
# ../data/raw/data/mpd.slice.797000-797999.json
# ../data/raw/data/mpd.slice.579000-579999.json
# ../data/raw/data/mpd.slice.314000-314999.json
# ../data/raw/data/mpd.slice.944000-944999.json
# ../data/raw/data/mpd.slice.412000-412999.json
# ../data/raw/data/mpd.slice.748000-748999.json
# ../data/raw/data/mpd.slice.215000-215999.json
# ../data/raw/data/mpd.slice.19000-19999.json
# ../data/raw/data/mpd.slice.845000-845999.json
# ../data/raw/data/mpd.slice.513000-513999.json
# ../data/raw/data/mpd.slice.2000-2999.json
# ../data/raw/data/mpd.slice.649000-649999.json
# ../data/raw/data/mpd.slice.722000-722999.json
# ../data/raw/data/mpd.slice.696000-696999.json
# ../data/raw/data/mpd.slice.478000-478999.json
# ../data/raw/data/mpd.slice.190000-190999.json
# ../data/raw/data/mpd.slice.540000-540999.json
# ../data/raw/data/mpd.slice.816000-816999.json
# ../data/raw/data/mpd.slice.246000-246999.json
# ../data/raw/data/mpd.slice.37000-37999.json
# ../data/raw/data/mpd.slice.299000-299999.json
# ../data/raw/data/mpd.slice.771000-771999.json
# ../data/raw/data/mpd.slice.176000-176999.json
# ../data/raw/data/mpd.slice.398000-398999.json
# ../data/raw/data/mpd.slice.670000-670999.json
# ../data/raw/data/mpd.slice.441000-441999.json
# ../data/raw/data/mpd.slice.917000-917999.json
# ../data/raw/data/mpd.slice.347000-347999.json
# ../data/raw/data/mpd.slice.374000-374999.json
# ../data/raw/data/mpd.slice.472000-472999.json
# ../data/raw/data/mpd.slice.924000-924999.json
# ../data/raw/data/mpd.slice.728000-728999.json
# ../data/raw/data/mpd.slice.890000-890999.json
# ../data/raw/data/mpd.slice.643000-643999.json
# ../data/raw/data/mpd.slice.145000-145999.json
# ../data/raw/data/mpd.slice.519000-519999.json
# ../data/raw/data/mpd.slice.742000-742999.json
# ../data/raw/data/mpd.slice.13000-13999.json
# ../data/raw/data/mpd.slice.418000-418999.json
# ../data/raw/data/mpd.slice.8000-8999.json
# ../data/raw/data/mpd.slice.275000-275999.json
# ../data/raw/data/mpd.slice.573000-573999.json
# ../data/raw/data/mpd.slice.825000-825999.json
# ../data/raw/data/mpd.slice.629000-629999.json
# ../data/raw/data/mpd.slice.991000-991999.json
# ../data/raw/data/mpd.slice.770000-770999.json
# ../data/raw/data/mpd.slice.298000-298999.json
# ../data/raw/data/mpd.slice.247000-247999.json
# ../data/raw/data/mpd.slice.541000-541999.json
# ../data/raw/data/mpd.slice.817000-817999.json
# ../data/raw/data/mpd.slice.41000-41999.json
# ../data/raw/data/mpd.slice.346000-346999.json
# ../data/raw/data/mpd.slice.440000-440999.json
# ../data/raw/data/mpd.slice.916000-916999.json
# ../data/raw/data/mpd.slice.671000-671999.json
# ../data/raw/data/mpd.slice.399000-399999.json
# ../data/raw/data/mpd.slice.177000-177999.json
# ../data/raw/data/mpd.slice.94000-94999.json
# ../data/raw/data/mpd.slice.144000-144999.json
# ../data/raw/data/mpd.slice.642000-642999.json
# ../data/raw/data/mpd.slice.518000-518999.json
# ../data/raw/data/mpd.slice.473000-473999.json
# ../data/raw/data/mpd.slice.925000-925999.json
# ../data/raw/data/mpd.slice.375000-375999.json
# ../data/raw/data/mpd.slice.891000-891999.json
# ../data/raw/data/mpd.slice.729000-729999.json
# ../data/raw/data/mpd.slice.572000-572999.json
# ../data/raw/data/mpd.slice.824000-824999.json
# ../data/raw/data/mpd.slice.274000-274999.json
# ../data/raw/data/mpd.slice.990000-990999.json
# ../data/raw/data/mpd.slice.628000-628999.json
# ../data/raw/data/mpd.slice.743000-743999.json
# ../data/raw/data/mpd.slice.419000-419999.json
# ../data/raw/data/mpd.slice.65000-65999.json
# ../data/raw/data/mpd.slice.528000-528999.json
# ../data/raw/data/mpd.slice.174000-174999.json
# ../data/raw/data/mpd.slice.672000-672999.json
# ../data/raw/data/mpd.slice.719000-719999.json
# ../data/raw/data/mpd.slice.915000-915999.json
# ../data/raw/data/mpd.slice.443000-443999.json
# ../data/raw/data/mpd.slice.345000-345999.json
# ../data/raw/data/mpd.slice.618000-618999.json
# ../data/raw/data/mpd.slice.814000-814999.json
# ../data/raw/data/mpd.slice.542000-542999.json
# ../data/raw/data/mpd.slice.244000-244999.json
# ../data/raw/data/mpd.slice.429000-429999.json
# ../data/raw/data/mpd.slice.773000-773999.json
# ../data/raw/data/mpd.slice.60000-60999.json
# ../data/raw/data/mpd.slice.740000-740999.json
# ../data/raw/data/mpd.slice.993000-993999.json
# ../data/raw/data/mpd.slice.277000-277999.json
# ../data/raw/data/mpd.slice.827000-827999.json
# ../data/raw/data/mpd.slice.571000-571999.json
# ../data/raw/data/mpd.slice.44000-44999.json
# ../data/raw/data/mpd.slice.892000-892999.json
# ../data/raw/data/mpd.slice.376000-376999.json
# ../data/raw/data/mpd.slice.926000-926999.json
# ../data/raw/data/mpd.slice.470000-470999.json
# ../data/raw/data/mpd.slice.198000-198999.json
# ../data/raw/data/mpd.slice.91000-91999.json
# ../data/raw/data/mpd.slice.641000-641999.json
# ../data/raw/data/mpd.slice.147000-147999.json
# ../data/raw/data/mpd.slice.718000-718999.json
# ../data/raw/data/mpd.slice.344000-344999.json
# ../data/raw/data/mpd.slice.914000-914999.json
# ../data/raw/data/mpd.slice.442000-442999.json
# ../data/raw/data/mpd.slice.529000-529999.json
# ../data/raw/data/mpd.slice.673000-673999.json
# ../data/raw/data/mpd.slice.175000-175999.json
# ../data/raw/data/mpd.slice.428000-428999.json
# ../data/raw/data/mpd.slice.772000-772999.json
# ../data/raw/data/mpd.slice.16000-16999.json
# ../data/raw/data/mpd.slice.619000-619999.json
# ../data/raw/data/mpd.slice.245000-245999.json
# ../data/raw/data/mpd.slice.815000-815999.json
# ../data/raw/data/mpd.slice.543000-543999.json
# ../data/raw/data/mpd.slice.992000-992999.json
# ../data/raw/data/mpd.slice.826000-826999.json
# ../data/raw/data/mpd.slice.570000-570999.json
# ../data/raw/data/mpd.slice.32000-32999.json
# ../data/raw/data/mpd.slice.276000-276999.json
# ../data/raw/data/mpd.slice.741000-741999.json
# ../data/raw/data/mpd.slice.146000-146999.json
# ../data/raw/data/mpd.slice.640000-640999.json
# ../data/raw/data/mpd.slice.893000-893999.json
# ../data/raw/data/mpd.slice.9000-9999.json
# ../data/raw/data/mpd.slice.199000-199999.json
# ../data/raw/data/mpd.slice.927000-927999.json
# ../data/raw/data/mpd.slice.471000-471999.json
# ../data/raw/data/mpd.slice.28000-28999.json
# ../data/raw/data/mpd.slice.377000-377999.json
# ../data/raw/data/mpd.slice.880000-880999.json
# ../data/raw/data/mpd.slice.738000-738999.json
# ../data/raw/data/mpd.slice.934000-934999.json
# ../data/raw/data/mpd.slice.462000-462999.json
# ../data/raw/data/mpd.slice.364000-364999.json
# ../data/raw/data/mpd.slice.509000-509999.json
# ../data/raw/data/mpd.slice.155000-155999.json
# ../data/raw/data/mpd.slice.653000-653999.json
# ../data/raw/data/mpd.slice.408000-408999.json
# ../data/raw/data/mpd.slice.10000-10999.json
# ../data/raw/data/mpd.slice.752000-752999.json
# ../data/raw/data/mpd.slice.981000-981999.json
# ../data/raw/data/mpd.slice.639000-639999.json
# ../data/raw/data/mpd.slice.835000-835999.json
# ../data/raw/data/mpd.slice.563000-563999.json
# ../data/raw/data/mpd.slice.265000-265999.json
# ../data/raw/data/mpd.slice.34000-34999.json
# ../data/raw/data/mpd.slice.256000-256999.json
# ../data/raw/data/mpd.slice.806000-806999.json
# ../data/raw/data/mpd.slice.550000-550999.json
# ../data/raw/data/mpd.slice.289000-289999.json
# ../data/raw/data/mpd.slice.761000-761999.json
# ../data/raw/data/mpd.slice.388000-388999.json
# ../data/raw/data/mpd.slice.660000-660999.json
# ../data/raw/data/mpd.slice.166000-166999.json
# ../data/raw/data/mpd.slice.357000-357999.json
# ../data/raw/data/mpd.slice.907000-907999.json
# ../data/raw/data/mpd.slice.451000-451999.json
# ../data/raw/data/mpd.slice.508000-508999.json
# ../data/raw/data/mpd.slice.652000-652999.json
# ../data/raw/data/mpd.slice.154000-154999.json
# ../data/raw/data/mpd.slice.739000-739999.json
# ../data/raw/data/mpd.slice.881000-881999.json
# ../data/raw/data/mpd.slice.365000-365999.json
# ../data/raw/data/mpd.slice.935000-935999.json
# ../data/raw/data/mpd.slice.463000-463999.json
# ../data/raw/data/mpd.slice.638000-638999.json
# ../data/raw/data/mpd.slice.980000-980999.json
# ../data/raw/data/mpd.slice.264000-264999.json
# ../data/raw/data/mpd.slice.834000-834999.json
# ../data/raw/data/mpd.slice.562000-562999.json
# ../data/raw/data/mpd.slice.66000-66999.json
# ../data/raw/data/mpd.slice.409000-409999.json
# ../data/raw/data/mpd.slice.753000-753999.json
# ../data/raw/data/mpd.slice.760000-760999.json
# ../data/raw/data/mpd.slice.288000-288999.json
# ../data/raw/data/mpd.slice.42000-42999.json
# ../data/raw/data/mpd.slice.807000-807999.json
# ../data/raw/data/mpd.slice.551000-551999.json
# ../data/raw/data/mpd.slice.257000-257999.json
# ../data/raw/data/mpd.slice.58000-58999.json
# ../data/raw/data/mpd.slice.906000-906999.json
# ../data/raw/data/mpd.slice.450000-450999.json
# ../data/raw/data/mpd.slice.356000-356999.json
# ../data/raw/data/mpd.slice.97000-97999.json
# ../data/raw/data/mpd.slice.167000-167999.json
# ../data/raw/data/mpd.slice.661000-661999.json
# ../data/raw/data/mpd.slice.389000-389999.json
# ../data/raw/data/mpd.slice.88000-88999.json
# ../data/raw/data/mpd.slice.750000-750999.json
# ../data/raw/data/mpd.slice.561000-561999.json
# ../data/raw/data/mpd.slice.837000-837999.json
# ../data/raw/data/mpd.slice.47000-47999.json
# ../data/raw/data/mpd.slice.267000-267999.json
# ../data/raw/data/mpd.slice.983000-983999.json
# ../data/raw/data/mpd.slice.460000-460999.json
# ../data/raw/data/mpd.slice.936000-936999.json
# ../data/raw/data/mpd.slice.188000-188999.json
# ../data/raw/data/mpd.slice.366000-366999.json
# ../data/raw/data/mpd.slice.882000-882999.json
# ../data/raw/data/mpd.slice.92000-92999.json
# ../data/raw/data/mpd.slice.157000-157999.json
# ../data/raw/data/mpd.slice.651000-651999.json
# ../data/raw/data/mpd.slice.662000-662999.json
# ../data/raw/data/mpd.slice.79000-79999.json
# ../data/raw/data/mpd.slice.164000-164999.json
# ../data/raw/data/mpd.slice.538000-538999.json
# ../data/raw/data/mpd.slice.355000-355999.json
# ../data/raw/data/mpd.slice.453000-453999.json
# ../data/raw/data/mpd.slice.905000-905999.json
# ../data/raw/data/mpd.slice.709000-709999.json
# ../data/raw/data/mpd.slice.254000-254999.json
# ../data/raw/data/mpd.slice.552000-552999.json
# ../data/raw/data/mpd.slice.804000-804999.json
# ../data/raw/data/mpd.slice.608000-608999.json
# ../data/raw/data/mpd.slice.763000-763999.json
# ../data/raw/data/mpd.slice.63000-63999.json
# ../data/raw/data/mpd.slice.439000-439999.json
# ../data/raw/data/mpd.slice.266000-266999.json
# ../data/raw/data/mpd.slice.560000-560999.json
# ../data/raw/data/mpd.slice.836000-836999.json
# ../data/raw/data/mpd.slice.31000-31999.json
# ../data/raw/data/mpd.slice.982000-982999.json
# ../data/raw/data/mpd.slice.751000-751999.json
# ../data/raw/data/mpd.slice.650000-650999.json
# ../data/raw/data/mpd.slice.156000-156999.json
# ../data/raw/data/mpd.slice.0-999.json
# ../data/raw/data/mpd.slice.367000-367999.json
# ../data/raw/data/mpd.slice.189000-189999.json
# ../data/raw/data/mpd.slice.461000-461999.json
# ../data/raw/data/mpd.slice.937000-937999.json
# ../data/raw/data/mpd.slice.883000-883999.json
# ../data/raw/data/mpd.slice.452000-452999.json
# ../data/raw/data/mpd.slice.904000-904999.json
# ../data/raw/data/mpd.slice.354000-354999.json
# ../data/raw/data/mpd.slice.708000-708999.json
# ../data/raw/data/mpd.slice.165000-165999.json
# ../data/raw/data/mpd.slice.663000-663999.json
# ../data/raw/data/mpd.slice.539000-539999.json
# ../data/raw/data/mpd.slice.762000-762999.json
# ../data/raw/data/mpd.slice.15000-15999.json
# ../data/raw/data/mpd.slice.438000-438999.json
# ../data/raw/data/mpd.slice.553000-553999.json
# ../data/raw/data/mpd.slice.805000-805999.json
# ../data/raw/data/mpd.slice.255000-255999.json
# ../data/raw/data/mpd.slice.609000-609999.json
# ../data/raw/data/mpd.slice.731000-731999.json
# ../data/raw/data/mpd.slice.889000-889999.json
# ../data/raw/data/mpd.slice.685000-685999.json
# ../data/raw/data/mpd.slice.183000-183999.json
# ../data/raw/data/mpd.slice.206000-206999.json
# ../data/raw/data/mpd.slice.856000-856999.json
# ../data/raw/data/mpd.slice.500000-500999.json
# ../data/raw/data/mpd.slice.307000-307999.json
# ../data/raw/data/mpd.slice.957000-957999.json
# ../data/raw/data/mpd.slice.401000-401999.json
# ../data/raw/data/mpd.slice.630000-630999.json
# ../data/raw/data/mpd.slice.136000-136999.json
# ../data/raw/data/mpd.slice.988000-988999.json
# ../data/raw/data/mpd.slice.21000-21999.json
# ../data/raw/data/mpd.slice.784000-784999.json
# ../data/raw/data/mpd.slice.105000-105999.json
# ../data/raw/data/mpd.slice.603000-603999.json
# ../data/raw/data/mpd.slice.559000-559999.json
# ../data/raw/data/mpd.slice.964000-964999.json
# ../data/raw/data/mpd.slice.432000-432999.json
# ../data/raw/data/mpd.slice.334000-334999.json
# ../data/raw/data/mpd.slice.586000-586999.json
# ../data/raw/data/mpd.slice.768000-768999.json
# ../data/raw/data/mpd.slice.280000-280999.json
# ../data/raw/data/mpd.slice.865000-865999.json
# ../data/raw/data/mpd.slice.533000-533999.json
# ../data/raw/data/mpd.slice.235000-235999.json
# ../data/raw/data/mpd.slice.487000-487999.json
# ../data/raw/data/mpd.slice.669000-669999.json
# ../data/raw/data/mpd.slice.381000-381999.json
# ../data/raw/data/mpd.slice.702000-702999.json
# ../data/raw/data/mpd.slice.458000-458999.json
# ../data/raw/data/mpd.slice.857000-857999.json
# ../data/raw/data/mpd.slice.501000-501999.json
# ../data/raw/data/mpd.slice.207000-207999.json
# ../data/raw/data/mpd.slice.82000-82999.json
# ../data/raw/data/mpd.slice.888000-888999.json
# ../data/raw/data/mpd.slice.730000-730999.json
# ../data/raw/data/mpd.slice.182000-182999.json
# ../data/raw/data/mpd.slice.684000-684999.json
# ../data/raw/data/mpd.slice.989000-989999.json
# ../data/raw/data/mpd.slice.137000-137999.json
# ../data/raw/data/mpd.slice.631000-631999.json
# ../data/raw/data/mpd.slice.57000-57999.json
# ../data/raw/data/mpd.slice.785000-785999.json
# ../data/raw/data/mpd.slice.956000-956999.json
# ../data/raw/data/mpd.slice.400000-400999.json
# ../data/raw/data/mpd.slice.306000-306999.json
# ../data/raw/data/mpd.slice.98000-98999.json
# ../data/raw/data/mpd.slice.335000-335999.json
# ../data/raw/data/mpd.slice.965000-965999.json
# ../data/raw/data/mpd.slice.433000-433999.json
# ../data/raw/data/mpd.slice.73000-73999.json
# ../data/raw/data/mpd.slice.281000-281999.json
# ../data/raw/data/mpd.slice.769000-769999.json
# ../data/raw/data/mpd.slice.587000-587999.json
# ../data/raw/data/mpd.slice.602000-602999.json
# ../data/raw/data/mpd.slice.104000-104999.json
# ../data/raw/data/mpd.slice.558000-558999.json
# ../data/raw/data/mpd.slice.703000-703999.json
# ../data/raw/data/mpd.slice.459000-459999.json
# ../data/raw/data/mpd.slice.234000-234999.json
# ../data/raw/data/mpd.slice.864000-864999.json
# ../data/raw/data/mpd.slice.532000-532999.json
# ../data/raw/data/mpd.slice.380000-380999.json
# ../data/raw/data/mpd.slice.668000-668999.json
# ../data/raw/data/mpd.slice.69000-69999.json
# ../data/raw/data/mpd.slice.486000-486999.json
# ../data/raw/data/mpd.slice.759000-759999.json
# ../data/raw/data/mpd.slice.305000-305999.json
# ../data/raw/data/mpd.slice.403000-403999.json
# ../data/raw/data/mpd.slice.955000-955999.json
# ../data/raw/data/mpd.slice.76000-76999.json
# ../data/raw/data/mpd.slice.786000-786999.json
# ../data/raw/data/mpd.slice.568000-568999.json
# ../data/raw/data/mpd.slice.632000-632999.json
# ../data/raw/data/mpd.slice.134000-134999.json
# ../data/raw/data/mpd.slice.687000-687999.json
# ../data/raw/data/mpd.slice.181000-181999.json
# ../data/raw/data/mpd.slice.469000-469999.json
# ../data/raw/data/mpd.slice.733000-733999.json
# ../data/raw/data/mpd.slice.658000-658999.json
# ../data/raw/data/mpd.slice.204000-204999.json
# ../data/raw/data/mpd.slice.502000-502999.json
# ../data/raw/data/mpd.slice.854000-854999.json
# ../data/raw/data/mpd.slice.485000-485999.json
# ../data/raw/data/mpd.slice.383000-383999.json
# ../data/raw/data/mpd.slice.87000-87999.json
# ../data/raw/data/mpd.slice.531000-531999.json
# ../data/raw/data/mpd.slice.867000-867999.json
# ../data/raw/data/mpd.slice.237000-237999.json
# ../data/raw/data/mpd.slice.48000-48999.json
# ../data/raw/data/mpd.slice.700000-700999.json
# ../data/raw/data/mpd.slice.107000-107999.json
# ../data/raw/data/mpd.slice.601000-601999.json
# ../data/raw/data/mpd.slice.52000-52999.json
# ../data/raw/data/mpd.slice.584000-584999.json
# ../data/raw/data/mpd.slice.282000-282999.json
# ../data/raw/data/mpd.slice.430000-430999.json
# ../data/raw/data/mpd.slice.966000-966999.json
# ../data/raw/data/mpd.slice.336000-336999.json
# ../data/raw/data/mpd.slice.569000-569999.json
# ../data/raw/data/mpd.slice.787000-787999.json
# ../data/raw/data/mpd.slice.135000-135999.json
# ../data/raw/data/mpd.slice.633000-633999.json
# ../data/raw/data/mpd.slice.758000-758999.json
# ../data/raw/data/mpd.slice.402000-402999.json
# ../data/raw/data/mpd.slice.954000-954999.json
# ../data/raw/data/mpd.slice.304000-304999.json
# ../data/raw/data/mpd.slice.659000-659999.json
# ../data/raw/data/mpd.slice.503000-503999.json
# ../data/raw/data/mpd.slice.855000-855999.json
# ../data/raw/data/mpd.slice.205000-205999.json
# ../data/raw/data/mpd.slice.468000-468999.json
# ../data/raw/data/mpd.slice.180000-180999.json
# ../data/raw/data/mpd.slice.686000-686999.json
# ../data/raw/data/mpd.slice.732000-732999.json
# ../data/raw/data/mpd.slice.701000-701999.json
# ../data/raw/data/mpd.slice.382000-382999.json
# ../data/raw/data/mpd.slice.484000-484999.json
# ../data/raw/data/mpd.slice.236000-236999.json
# ../data/raw/data/mpd.slice.530000-530999.json
# ../data/raw/data/mpd.slice.866000-866999.json
# ../data/raw/data/mpd.slice.283000-283999.json
# ../data/raw/data/mpd.slice.585000-585999.json
# ../data/raw/data/mpd.slice.337000-337999.json
# ../data/raw/data/mpd.slice.431000-431999.json
# ../data/raw/data/mpd.slice.967000-967999.json
# ../data/raw/data/mpd.slice.600000-600999.json
# ../data/raw/data/mpd.slice.24000-24999.json
# ../data/raw/data/mpd.slice.106000-106999.json
# ../data/raw/data/mpd.slice.941000-941999.json
# ../data/raw/data/mpd.slice.417000-417999.json
# ../data/raw/data/mpd.slice.311000-311999.json
# ../data/raw/data/mpd.slice.5000-5999.json
# ../data/raw/data/mpd.slice.792000-792999.json
# ../data/raw/data/mpd.slice.120000-120999.json
# ../data/raw/data/mpd.slice.626000-626999.json
# ../data/raw/data/mpd.slice.195000-195999.json
# ../data/raw/data/mpd.slice.14000-14999.json
# ../data/raw/data/mpd.slice.693000-693999.json
# ../data/raw/data/mpd.slice.727000-727999.json
# ../data/raw/data/mpd.slice.840000-840999.json
# ../data/raw/data/mpd.slice.516000-516999.json
# ../data/raw/data/mpd.slice.210000-210999.json
# ../data/raw/data/mpd.slice.30000-30999.json
# ../data/raw/data/mpd.slice.397000-397999.json
# ../data/raw/data/mpd.slice.491000-491999.json
# ../data/raw/data/mpd.slice.179000-179999.json
# ../data/raw/data/mpd.slice.223000-223999.json
# ../data/raw/data/mpd.slice.873000-873999.json
# ../data/raw/data/mpd.slice.525000-525999.json
# ../data/raw/data/mpd.slice.348000-348999.json
# ../data/raw/data/mpd.slice.1000-1999.json
# ../data/raw/data/mpd.slice.918000-918999.json
# ../data/raw/data/mpd.slice.714000-714999.json
# ../data/raw/data/mpd.slice.249000-249999.json
# ../data/raw/data/mpd.slice.819000-819999.json
# ../data/raw/data/mpd.slice.615000-615999.json
# ../data/raw/data/mpd.slice.113000-113999.json
# ../data/raw/data/mpd.slice.296000-296999.json
# ../data/raw/data/mpd.slice.590000-590999.json
# ../data/raw/data/mpd.slice.322000-322999.json
# ../data/raw/data/mpd.slice.972000-972999.json
# ../data/raw/data/mpd.slice.424000-424999.json
# ../data/raw/data/mpd.slice.793000-793999.json
# ../data/raw/data/mpd.slice.78000-78999.json
# ../data/raw/data/mpd.slice.627000-627999.json
# ../data/raw/data/mpd.slice.121000-121999.json
# ../data/raw/data/mpd.slice.310000-310999.json
# ../data/raw/data/mpd.slice.940000-940999.json
# ../data/raw/data/mpd.slice.416000-416999.json
# ../data/raw/data/mpd.slice.211000-211999.json
# ../data/raw/data/mpd.slice.841000-841999.json
# ../data/raw/data/mpd.slice.517000-517999.json
# ../data/raw/data/mpd.slice.692000-692999.json
# ../data/raw/data/mpd.slice.62000-62999.json
# ../data/raw/data/mpd.slice.194000-194999.json
# ../data/raw/data/mpd.slice.726000-726999.json
# ../data/raw/data/mpd.slice.919000-919999.json
# ../data/raw/data/mpd.slice.89000-89999.json
# ../data/raw/data/mpd.slice.349000-349999.json
# ../data/raw/data/mpd.slice.715000-715999.json
# ../data/raw/data/mpd.slice.178000-178999.json
# ../data/raw/data/mpd.slice.490000-490999.json
# ../data/raw/data/mpd.slice.46000-46999.json
# ../data/raw/data/mpd.slice.396000-396999.json
# ../data/raw/data/mpd.slice.872000-872999.json
# ../data/raw/data/mpd.slice.524000-524999.json
# ../data/raw/data/mpd.slice.222000-222999.json
# ../data/raw/data/mpd.slice.591000-591999.json
# ../data/raw/data/mpd.slice.297000-297999.json
# ../data/raw/data/mpd.slice.973000-973999.json
# ../data/raw/data/mpd.slice.425000-425999.json
# ../data/raw/data/mpd.slice.323000-323999.json
# ../data/raw/data/mpd.slice.818000-818999.json
# ../data/raw/data/mpd.slice.93000-93999.json
# ../data/raw/data/mpd.slice.248000-248999.json
# ../data/raw/data/mpd.slice.112000-112999.json
# ../data/raw/data/mpd.slice.614000-614999.json
# ../data/raw/data/mpd.slice.725000-725999.json
# ../data/raw/data/mpd.slice.929000-929999.json
# ../data/raw/data/mpd.slice.197000-197999.json
# ../data/raw/data/mpd.slice.379000-379999.json
# ../data/raw/data/mpd.slice.691000-691999.json
# ../data/raw/data/mpd.slice.514000-514999.json
# ../data/raw/data/mpd.slice.842000-842999.json
# ../data/raw/data/mpd.slice.212000-212999.json
# ../data/raw/data/mpd.slice.43000-43999.json
# ../data/raw/data/mpd.slice.148000-148999.json
# ../data/raw/data/mpd.slice.415000-415999.json
# ../data/raw/data/mpd.slice.943000-943999.json
# ../data/raw/data/mpd.slice.59000-59999.json
# ../data/raw/data/mpd.slice.313000-313999.json
# ../data/raw/data/mpd.slice.96000-96999.json
# ../data/raw/data/mpd.slice.122000-122999.json
# ../data/raw/data/mpd.slice.624000-624999.json
# ../data/raw/data/mpd.slice.828000-828999.json
# ../data/raw/data/mpd.slice.278000-278999.json
# ../data/raw/data/mpd.slice.790000-790999.json
# ../data/raw/data/mpd.slice.617000-617999.json
# ../data/raw/data/mpd.slice.111000-111999.json
# ../data/raw/data/mpd.slice.320000-320999.json
# ../data/raw/data/mpd.slice.426000-426999.json
# ../data/raw/data/mpd.slice.970000-970999.json
# ../data/raw/data/mpd.slice.294000-294999.json
# ../data/raw/data/mpd.slice.592000-592999.json
# ../data/raw/data/mpd.slice.221000-221999.json
# ../data/raw/data/mpd.slice.527000-527999.json
# ../data/raw/data/mpd.slice.871000-871999.json
# ../data/raw/data/mpd.slice.395000-395999.json
# ../data/raw/data/mpd.slice.493000-493999.json
# ../data/raw/data/mpd.slice.716000-716999.json
# ../data/raw/data/mpd.slice.67000-67999.json
# ../data/raw/data/mpd.slice.213000-213999.json
# ../data/raw/data/mpd.slice.35000-35999.json
# ../data/raw/data/mpd.slice.515000-515999.json
# ../data/raw/data/mpd.slice.843000-843999.json
# ../data/raw/data/mpd.slice.149000-149999.json
# ../data/raw/data/mpd.slice.724000-724999.json
# ../data/raw/data/mpd.slice.4000-4999.json
# ../data/raw/data/mpd.slice.690000-690999.json
# ../data/raw/data/mpd.slice.378000-378999.json
# ../data/raw/data/mpd.slice.196000-196999.json
# ../data/raw/data/mpd.slice.928000-928999.json
# ../data/raw/data/mpd.slice.625000-625999.json
# ../data/raw/data/mpd.slice.123000-123999.json
# ../data/raw/data/mpd.slice.791000-791999.json
# ../data/raw/data/mpd.slice.279000-279999.json
# ../data/raw/data/mpd.slice.829000-829999.json
# ../data/raw/data/mpd.slice.312000-312999.json
# ../data/raw/data/mpd.slice.414000-414999.json
# ../data/raw/data/mpd.slice.942000-942999.json
# ../data/raw/data/mpd.slice.427000-427999.json
# ../data/raw/data/mpd.slice.971000-971999.json
# ../data/raw/data/mpd.slice.321000-321999.json
# ../data/raw/data/mpd.slice.593000-593999.json
# ../data/raw/data/mpd.slice.295000-295999.json
# ../data/raw/data/mpd.slice.110000-110999.json
# ../data/raw/data/mpd.slice.616000-616999.json
# ../data/raw/data/mpd.slice.11000-11999.json
# ../data/raw/data/mpd.slice.717000-717999.json
# ../data/raw/data/mpd.slice.526000-526999.json
# ../data/raw/data/mpd.slice.870000-870999.json
# ../data/raw/data/mpd.slice.220000-220999.json
# ../data/raw/data/mpd.slice.492000-492999.json
# ../data/raw/data/mpd.slice.394000-394999.json
# ../data/raw/data/mpd.slice.744000-744999.json
# ../data/raw/data/mpd.slice.318000-318999.json
# ../data/raw/data/mpd.slice.948000-948999.json
# ../data/raw/data/mpd.slice.273000-273999.json
# ../data/raw/data/mpd.slice.823000-823999.json
# ../data/raw/data/mpd.slice.575000-575999.json
# ../data/raw/data/mpd.slice.129000-129999.json
# ../data/raw/data/mpd.slice.997000-997999.json
# ../data/raw/data/mpd.slice.372000-372999.json
# ../data/raw/data/mpd.slice.922000-922999.json
# ../data/raw/data/mpd.slice.474000-474999.json
# ../data/raw/data/mpd.slice.896000-896999.json
# ../data/raw/data/mpd.slice.645000-645999.json
# ../data/raw/data/mpd.slice.143000-143999.json
# ../data/raw/data/mpd.slice.219000-219999.json
# ../data/raw/data/mpd.slice.25000-25999.json
# ../data/raw/data/mpd.slice.849000-849999.json
# ../data/raw/data/mpd.slice.170000-170999.json
# ../data/raw/data/mpd.slice.498000-498999.json
# ../data/raw/data/mpd.slice.676000-676999.json
# ../data/raw/data/mpd.slice.911000-911999.json
# ../data/raw/data/mpd.slice.447000-447999.json
# ../data/raw/data/mpd.slice.341000-341999.json
# ../data/raw/data/mpd.slice.810000-810999.json
# ../data/raw/data/mpd.slice.546000-546999.json
# ../data/raw/data/mpd.slice.240000-240999.json
# ../data/raw/data/mpd.slice.599000-599999.json
# ../data/raw/data/mpd.slice.777000-777999.json
# ../data/raw/data/mpd.slice.822000-822999.json
# ../data/raw/data/mpd.slice.574000-574999.json
# ../data/raw/data/mpd.slice.272000-272999.json
# ../data/raw/data/mpd.slice.996000-996999.json
# ../data/raw/data/mpd.slice.128000-128999.json
# ../data/raw/data/mpd.slice.86000-86999.json
# ../data/raw/data/mpd.slice.745000-745999.json
# ../data/raw/data/mpd.slice.949000-949999.json
# ../data/raw/data/mpd.slice.319000-319999.json
# ../data/raw/data/mpd.slice.49000-49999.json
# ../data/raw/data/mpd.slice.142000-142999.json
# ../data/raw/data/mpd.slice.644000-644999.json
# ../data/raw/data/mpd.slice.53000-53999.json
# ../data/raw/data/mpd.slice.848000-848999.json
# ../data/raw/data/mpd.slice.218000-218999.json
# ../data/raw/data/mpd.slice.923000-923999.json
# ../data/raw/data/mpd.slice.475000-475999.json
# ../data/raw/data/mpd.slice.373000-373999.json
# ../data/raw/data/mpd.slice.897000-897999.json
# ../data/raw/data/mpd.slice.340000-340999.json
# ../data/raw/data/mpd.slice.910000-910999.json
# ../data/raw/data/mpd.slice.446000-446999.json
# ../data/raw/data/mpd.slice.77000-77999.json
# ../data/raw/data/mpd.slice.677000-677999.json
# ../data/raw/data/mpd.slice.499000-499999.json
# ../data/raw/data/mpd.slice.171000-171999.json
# ../data/raw/data/mpd.slice.776000-776999.json
# ../data/raw/data/mpd.slice.598000-598999.json
# ../data/raw/data/mpd.slice.241000-241999.json
# ../data/raw/data/mpd.slice.811000-811999.json
# ../data/raw/data/mpd.slice.547000-547999.json
# ../data/raw/data/mpd.slice.894000-894999.json
# ../data/raw/data/mpd.slice.698000-698999.json
# ../data/raw/data/mpd.slice.370000-370999.json
# ../data/raw/data/mpd.slice.476000-476999.json
# ../data/raw/data/mpd.slice.920000-920999.json
# ../data/raw/data/mpd.slice.72000-72999.json
# ../data/raw/data/mpd.slice.647000-647999.json
# ../data/raw/data/mpd.slice.141000-141999.json
# ../data/raw/data/mpd.slice.746000-746999.json
# ../data/raw/data/mpd.slice.995000-995999.json
# ../data/raw/data/mpd.slice.799000-799999.json
# ../data/raw/data/mpd.slice.271000-271999.json
# ../data/raw/data/mpd.slice.68000-68999.json
# ../data/raw/data/mpd.slice.577000-577999.json
# ../data/raw/data/mpd.slice.821000-821999.json
# ../data/raw/data/mpd.slice.118000-118999.json
# ../data/raw/data/mpd.slice.83000-83999.json
# ../data/raw/data/mpd.slice.544000-544999.json
# ../data/raw/data/mpd.slice.812000-812999.json
# ../data/raw/data/mpd.slice.242000-242999.json
# ../data/raw/data/mpd.slice.979000-979999.json
# ../data/raw/data/mpd.slice.329000-329999.json
# ../data/raw/data/mpd.slice.775000-775999.json
# ../data/raw/data/mpd.slice.878000-878999.json
# ../data/raw/data/mpd.slice.228000-228999.json
# ../data/raw/data/mpd.slice.172000-172999.json
# ../data/raw/data/mpd.slice.56000-56999.json
# ../data/raw/data/mpd.slice.674000-674999.json
# ../data/raw/data/mpd.slice.445000-445999.json
# ../data/raw/data/mpd.slice.913000-913999.json
# ../data/raw/data/mpd.slice.99000-99999.json
# ../data/raw/data/mpd.slice.343000-343999.json
# ../data/raw/data/mpd.slice.140000-140999.json
# ../data/raw/data/mpd.slice.646000-646999.json
# ../data/raw/data/mpd.slice.895000-895999.json
# ../data/raw/data/mpd.slice.477000-477999.json
# ../data/raw/data/mpd.slice.921000-921999.json
# ../data/raw/data/mpd.slice.371000-371999.json
# ../data/raw/data/mpd.slice.699000-699999.json
# ../data/raw/data/mpd.slice.994000-994999.json
# ../data/raw/data/mpd.slice.576000-576999.json
# ../data/raw/data/mpd.slice.820000-820999.json
# ../data/raw/data/mpd.slice.270000-270999.json
# ../data/raw/data/mpd.slice.798000-798999.json
# ../data/raw/data/mpd.slice.747000-747999.json
# ../data/raw/data/mpd.slice.328000-328999.json
# ../data/raw/data/mpd.slice.978000-978999.json
# ../data/raw/data/mpd.slice.774000-774999.json
# ../data/raw/data/mpd.slice.119000-119999.json
# ../data/raw/data/mpd.slice.243000-243999.json
# ../data/raw/data/mpd.slice.545000-545999.json
# ../data/raw/data/mpd.slice.813000-813999.json
# ../data/raw/data/mpd.slice.342000-342999.json
# ../data/raw/data/mpd.slice.444000-444999.json
# ../data/raw/data/mpd.slice.912000-912999.json
# ../data/raw/data/mpd.slice.229000-229999.json
# ../data/raw/data/mpd.slice.879000-879999.json
# ../data/raw/data/mpd.slice.675000-675999.json
# ../data/raw/data/mpd.slice.173000-173999.json
# ../data/raw/data/mpd.slice.20000-20999.json
# ../data/raw/data/mpd.slice.666000-666999.json
# ../data/raw/data/mpd.slice.160000-160999.json
# ../data/raw/data/mpd.slice.488000-488999.json
# ../data/raw/data/mpd.slice.351000-351999.json
# ../data/raw/data/mpd.slice.457000-457999.json
# ../data/raw/data/mpd.slice.901000-901999.json
# ../data/raw/data/mpd.slice.18000-18999.json
# ../data/raw/data/mpd.slice.250000-250999.json
# ../data/raw/data/mpd.slice.556000-556999.json
# ../data/raw/data/mpd.slice.800000-800999.json
# ../data/raw/data/mpd.slice.767000-767999.json
# ../data/raw/data/mpd.slice.589000-589999.json
# ../data/raw/data/mpd.slice.958000-958999.json
# ../data/raw/data/mpd.slice.308000-308999.json
# ../data/raw/data/mpd.slice.754000-754999.json
# ../data/raw/data/mpd.slice.139000-139999.json
# ../data/raw/data/mpd.slice.987000-987999.json
# ../data/raw/data/mpd.slice.565000-565999.json
# ../data/raw/data/mpd.slice.833000-833999.json
# ../data/raw/data/mpd.slice.263000-263999.json
# ../data/raw/data/mpd.slice.886000-886999.json
# ../data/raw/data/mpd.slice.464000-464999.json
# ../data/raw/data/mpd.slice.932000-932999.json
# ../data/raw/data/mpd.slice.362000-362999.json
# ../data/raw/data/mpd.slice.26000-26999.json
# ../data/raw/data/mpd.slice.859000-859999.json
# ../data/raw/data/mpd.slice.209000-209999.json
# ../data/raw/data/mpd.slice.153000-153999.json
# ../data/raw/data/mpd.slice.655000-655999.json
# ../data/raw/data/mpd.slice.74000-74999.json
# ../data/raw/data/mpd.slice.456000-456999.json
# ../data/raw/data/mpd.slice.900000-900999.json
# ../data/raw/data/mpd.slice.350000-350999.json
# ../data/raw/data/mpd.slice.489000-489999.json
# ../data/raw/data/mpd.slice.161000-161999.json
# ../data/raw/data/mpd.slice.667000-667999.json
# ../data/raw/data/mpd.slice.588000-588999.json
# ../data/raw/data/mpd.slice.766000-766999.json
# ../data/raw/data/mpd.slice.557000-557999.json
# ../data/raw/data/mpd.slice.801000-801999.json
# ../data/raw/data/mpd.slice.251000-251999.json
# ../data/raw/data/mpd.slice.85000-85999.json
# ../data/raw/data/mpd.slice.986000-986999.json
# ../data/raw/data/mpd.slice.138000-138999.json
# ../data/raw/data/mpd.slice.262000-262999.json
# ../data/raw/data/mpd.slice.564000-564999.json
# ../data/raw/data/mpd.slice.832000-832999.json
# ../data/raw/data/mpd.slice.309000-309999.json
# ../data/raw/data/mpd.slice.959000-959999.json
# ../data/raw/data/mpd.slice.755000-755999.json
# ../data/raw/data/mpd.slice.208000-208999.json
# ../data/raw/data/mpd.slice.50000-50999.json
# ../data/raw/data/mpd.slice.858000-858999.json
# ../data/raw/data/mpd.slice.654000-654999.json
# ../data/raw/data/mpd.slice.152000-152999.json
# ../data/raw/data/mpd.slice.887000-887999.json
# ../data/raw/data/mpd.slice.363000-363999.json
# ../data/raw/data/mpd.slice.465000-465999.json
# ../data/raw/data/mpd.slice.933000-933999.json
# ../data/raw/data/mpd.slice.80000-80999.json
# ../data/raw/data/mpd.slice.252000-252999.json
# ../data/raw/data/mpd.slice.802000-802999.json
# ../data/raw/data/mpd.slice.554000-554999.json
# ../data/raw/data/mpd.slice.108000-108999.json
# ../data/raw/data/mpd.slice.765000-765999.json
# ../data/raw/data/mpd.slice.339000-339999.json
# ../data/raw/data/mpd.slice.969000-969999.json
# ../data/raw/data/mpd.slice.664000-664999.json
# ../data/raw/data/mpd.slice.162000-162999.json
# ../data/raw/data/mpd.slice.55000-55999.json
# ../data/raw/data/mpd.slice.238000-238999.json
# ../data/raw/data/mpd.slice.868000-868999.json
# ../data/raw/data/mpd.slice.353000-353999.json
# ../data/raw/data/mpd.slice.903000-903999.json
# ../data/raw/data/mpd.slice.455000-455999.json
# ../data/raw/data/mpd.slice.930000-930999.json
# ../data/raw/data/mpd.slice.466000-466999.json
# ../data/raw/data/mpd.slice.688000-688999.json
# ../data/raw/data/mpd.slice.360000-360999.json
# ../data/raw/data/mpd.slice.71000-71999.json
# ../data/raw/data/mpd.slice.884000-884999.json
# ../data/raw/data/mpd.slice.151000-151999.json
# ../data/raw/data/mpd.slice.657000-657999.json
# ../data/raw/data/mpd.slice.756000-756999.json
# ../data/raw/data/mpd.slice.831000-831999.json
# ../data/raw/data/mpd.slice.567000-567999.json
# ../data/raw/data/mpd.slice.789000-789999.json
# ../data/raw/data/mpd.slice.261000-261999.json
# ../data/raw/data/mpd.slice.985000-985999.json
# ../data/raw/data/mpd.slice.39000-39999.json
# ../data/raw/data/mpd.slice.764000-764999.json
# ../data/raw/data/mpd.slice.968000-968999.json
# ../data/raw/data/mpd.slice.338000-338999.json
# ../data/raw/data/mpd.slice.803000-803999.json
# ../data/raw/data/mpd.slice.555000-555999.json
# ../data/raw/data/mpd.slice.253000-253999.json
# ../data/raw/data/mpd.slice.109000-109999.json
# ../data/raw/data/mpd.slice.902000-902999.json
# ../data/raw/data/mpd.slice.454000-454999.json
# ../data/raw/data/mpd.slice.352000-352999.json
# ../data/raw/data/mpd.slice.163000-163999.json
# ../data/raw/data/mpd.slice.23000-23999.json
# ../data/raw/data/mpd.slice.665000-665999.json
# ../data/raw/data/mpd.slice.869000-869999.json
# ../data/raw/data/mpd.slice.239000-239999.json
# ../data/raw/data/mpd.slice.656000-656999.json
# ../data/raw/data/mpd.slice.150000-150999.json
# ../data/raw/data/mpd.slice.361000-361999.json
# ../data/raw/data/mpd.slice.689000-689999.json
# ../data/raw/data/mpd.slice.931000-931999.json
# ../data/raw/data/mpd.slice.467000-467999.json
# ../data/raw/data/mpd.slice.885000-885999.json
# ../data/raw/data/mpd.slice.260000-260999.json
# ../data/raw/data/mpd.slice.788000-788999.json
# ../data/raw/data/mpd.slice.830000-830999.json
# ../data/raw/data/mpd.slice.566000-566999.json
# ../data/raw/data/mpd.slice.984000-984999.json
# ../data/raw/data/mpd.slice.757000-757999.json
# ../data/raw/data/mpd.slice.535000-535999.json
# ../data/raw/data/mpd.slice.863000-863999.json
# ../data/raw/data/mpd.slice.233000-233999.json
# ../data/raw/data/mpd.slice.481000-481999.json
# ../data/raw/data/mpd.slice.169000-169999.json
# ../data/raw/data/mpd.slice.33000-33999.json
# ../data/raw/data/mpd.slice.387000-387999.json
# ../data/raw/data/mpd.slice.704000-704999.json
# ../data/raw/data/mpd.slice.908000-908999.json
# ../data/raw/data/mpd.slice.358000-358999.json
# ../data/raw/data/mpd.slice.103000-103999.json
# ../data/raw/data/mpd.slice.605000-605999.json
# ../data/raw/data/mpd.slice.809000-809999.json
# ../data/raw/data/mpd.slice.259000-259999.json
# ../data/raw/data/mpd.slice.434000-434999.json
# ../data/raw/data/mpd.slice.962000-962999.json
# ../data/raw/data/mpd.slice.332000-332999.json
# ../data/raw/data/mpd.slice.580000-580999.json
# ../data/raw/data/mpd.slice.29000-29999.json
# ../data/raw/data/mpd.slice.286000-286999.json
# ../data/raw/data/mpd.slice.301000-301999.json
# ../data/raw/data/mpd.slice.407000-407999.json
# ../data/raw/data/mpd.slice.951000-951999.json
# ../data/raw/data/mpd.slice.636000-636999.json
# ../data/raw/data/mpd.slice.130000-130999.json
# ../data/raw/data/mpd.slice.782000-782999.json
# ../data/raw/data/mpd.slice.737000-737999.json
# ../data/raw/data/mpd.slice.683000-683999.json
# ../data/raw/data/mpd.slice.17000-17999.json
# ../data/raw/data/mpd.slice.185000-185999.json
# ../data/raw/data/mpd.slice.200000-200999.json
# ../data/raw/data/mpd.slice.506000-506999.json
# ../data/raw/data/mpd.slice.850000-850999.json
# ../data/raw/data/mpd.slice.705000-705999.json
# ../data/raw/data/mpd.slice.359000-359999.json
# ../data/raw/data/mpd.slice.909000-909999.json
# ../data/raw/data/mpd.slice.232000-232999.json
# ../data/raw/data/mpd.slice.534000-534999.json
# ../data/raw/data/mpd.slice.862000-862999.json
# ../data/raw/data/mpd.slice.386000-386999.json
# ../data/raw/data/mpd.slice.45000-45999.json
# ../data/raw/data/mpd.slice.168000-168999.json
# ../data/raw/data/mpd.slice.480000-480999.json
# ../data/raw/data/mpd.slice.333000-333999.json
# ../data/raw/data/mpd.slice.435000-435999.json
# ../data/raw/data/mpd.slice.963000-963999.json
# ../data/raw/data/mpd.slice.287000-287999.json
# ../data/raw/data/mpd.slice.581000-581999.json
# ../data/raw/data/mpd.slice.604000-604999.json
# ../data/raw/data/mpd.slice.102000-102999.json
# ../data/raw/data/mpd.slice.258000-258999.json
# ../data/raw/data/mpd.slice.808000-808999.json
# ../data/raw/data/mpd.slice.90000-90999.json
# ../data/raw/data/mpd.slice.131000-131999.json
# ../data/raw/data/mpd.slice.637000-637999.json
# ../data/raw/data/mpd.slice.783000-783999.json
# ../data/raw/data/mpd.slice.406000-406999.json
# ../data/raw/data/mpd.slice.950000-950999.json
# ../data/raw/data/mpd.slice.300000-300999.json
# ../data/raw/data/mpd.slice.507000-507999.json
# ../data/raw/data/mpd.slice.851000-851999.json
# ../data/raw/data/mpd.slice.201000-201999.json
# ../data/raw/data/mpd.slice.736000-736999.json
# ../data/raw/data/mpd.slice.61000-61999.json
# ../data/raw/data/mpd.slice.184000-184999.json
# ../data/raw/data/mpd.slice.682000-682999.json
# ../data/raw/data/mpd.slice.101000-101999.json
# ../data/raw/data/mpd.slice.607000-607999.json
# ../data/raw/data/mpd.slice.582000-582999.json
# ../data/raw/data/mpd.slice.284000-284999.json
# ../data/raw/data/mpd.slice.960000-960999.json
# ../data/raw/data/mpd.slice.436000-436999.json
# ../data/raw/data/mpd.slice.330000-330999.json
# ../data/raw/data/mpd.slice.483000-483999.json
# ../data/raw/data/mpd.slice.385000-385999.json
# ../data/raw/data/mpd.slice.861000-861999.json
# ../data/raw/data/mpd.slice.537000-537999.json
# ../data/raw/data/mpd.slice.231000-231999.json
# ../data/raw/data/mpd.slice.64000-64999.json
# ../data/raw/data/mpd.slice.706000-706999.json
# ../data/raw/data/mpd.slice.369000-369999.json
# ../data/raw/data/mpd.slice.681000-681999.json
# ../data/raw/data/mpd.slice.939000-939999.json
# ../data/raw/data/mpd.slice.187000-187999.json
# ../data/raw/data/mpd.slice.735000-735999.json
# ../data/raw/data/mpd.slice.158000-158999.json
# ../data/raw/data/mpd.slice.202000-202999.json
# ../data/raw/data/mpd.slice.40000-40999.json
# ../data/raw/data/mpd.slice.852000-852999.json
# ../data/raw/data/mpd.slice.504000-504999.json
# ../data/raw/data/mpd.slice.303000-303999.json
# ../data/raw/data/mpd.slice.953000-953999.json
# ../data/raw/data/mpd.slice.405000-405999.json
# ../data/raw/data/mpd.slice.268000-268999.json
# ../data/raw/data/mpd.slice.780000-780999.json
# ../data/raw/data/mpd.slice.838000-838999.json
# ../data/raw/data/mpd.slice.634000-634999.json
# ../data/raw/data/mpd.slice.95000-95999.json
# ../data/raw/data/mpd.slice.132000-132999.json
# ../data/raw/data/mpd.slice.285000-285999.json
# ../data/raw/data/mpd.slice.583000-583999.json
# ../data/raw/data/mpd.slice.331000-331999.json
# ../data/raw/data/mpd.slice.961000-961999.json
# ../data/raw/data/mpd.slice.437000-437999.json
# ../data/raw/data/mpd.slice.606000-606999.json
# ../data/raw/data/mpd.slice.100000-100999.json
# ../data/raw/data/mpd.slice.707000-707999.json
# ../data/raw/data/mpd.slice.12000-12999.json
# ../data/raw/data/mpd.slice.384000-384999.json
# ../data/raw/data/mpd.slice.482000-482999.json
# ../data/raw/data/mpd.slice.230000-230999.json
# ../data/raw/data/mpd.slice.860000-860999.json
# ../data/raw/data/mpd.slice.536000-536999.json
# ../data/raw/data/mpd.slice.159000-159999.json
# ../data/raw/data/mpd.slice.853000-853999.json
# ../data/raw/data/mpd.slice.505000-505999.json
# ../data/raw/data/mpd.slice.36000-36999.json
# ../data/raw/data/mpd.slice.203000-203999.json
# ../data/raw/data/mpd.slice.186000-186999.json
# ../data/raw/data/mpd.slice.938000-938999.json
# ../data/raw/data/mpd.slice.680000-680999.json
# ../data/raw/data/mpd.slice.368000-368999.json
# ../data/raw/data/mpd.slice.734000-734999.json
# ../data/raw/data/mpd.slice.839000-839999.json
# ../data/raw/data/mpd.slice.781000-781999.json
# ../data/raw/data/mpd.slice.269000-269999.json
# ../data/raw/data/mpd.slice.133000-133999.json
# ../data/raw/data/mpd.slice.635000-635999.json
# ../data/raw/data/mpd.slice.952000-952999.json
# ../data/raw/data/mpd.slice.404000-404999.json
# ../data/raw/data/mpd.slice.302000-302999.json

# %%
dft = pd.read_csv('df_data/df_tracks.csv')
dft
# Out:
#         Unnamed: 0                        album_name  \
# 0                0                               ABC
# 1                1              Everything Goes Numb
# 2                2  Thriller 25 Super Deluxe Edition
# 3                3                            Dookie
# 4                4                          Elephant
# ...            ...                               ...
# 110711      110711          Peliculas De Cine Vol. 2
# 110712      110712                    Sports Weekend
# 110713      110713                        Wild World
# 110714      110714                  Better Off Alone
# 110715      110715          Salsa Classics Revisited
#
#                                    album_uri                   artist_name  \
# 0       spotify:album:4GuzZh2dtsOjG3sMkx52eR                 The Jackson 5
# 1       spotify:album:3phH2ZoACvpLVcPtyIk8jp         Streetlight Manifesto
# 2       spotify:album:1C2h7mLntPSeVYciMRTF4a               Michael Jackson
# 3       spotify:album:4uG8q3GPuWHQlRbswMIRS6                     Green Day
# 4       spotify:album:4teFaDSeFHYXZjZJaZGrAO             The White Stripes
# ...                                      ...                           ...
# 110711  spotify:album:63Ayga8d1117BO6ECavJgA          The Royal Movie Band
# 110712  spotify:album:0S4qTNMIciayRUU4TXCYGR                   2 LIVE CREW
# 110713  spotify:album:0gtU58GVllHFpZzIgLd5lV                      Bastille
# 110714  spotify:album:4Bbi9dcZgtJiJqEkiclbpK                  Alice Deejay
# 110715  spotify:album:2QeEEn8jNy5SFx9coIzS3Z  El Gran Combo De Puerto Rico
#
#                                    artist_uri  duration_ms  \
# 0       spotify:artist:2iE18Oxc8YSumAU232n4rW       174866
# 1       spotify:artist:1OKOTYGoCE2buxTYMegJp7       327920
# 2       spotify:artist:3fMbdgg4jU18AjLCKBhRSm       293826
# 3       spotify:artist:7oPftvlwr6VrsViSDV7fJY       181533
# 4       spotify:artist:4F84IBURUo98rz4r61KF70       231800
# ...                                       ...          ...
# 110711  spotify:artist:1YMADOVqFTlVjZwbCOSp6c       223173
# 110712  spotify:artist:58Dx4HPzeOO3dbpD9YYEes       257640
# 110713  spotify:artist:7EQ0qTo7fWT7DPxmxtSYEc       183559
# 110714  spotify:artist:0aNCjE72yyrhKQB1qfPBpi       412426
# 110715  spotify:artist:6nnspeopmJAG07xOxHmqTu       339573
#
#                                track_name  \
# 0                                     ABC
# 1                      Point/Counterpoint
# 2                             Billie Jean
# 3                             Basket Case
# 4                       Seven Nation Army
# ...                                   ...
# 110711                            Starman
# 110712                     Pop That P--sy
# 110713                             Campus
# 110714  Better Off Alone - Vocal Club RMX
# 110715  Y No Hago Mas Na' - Reggaeton Mix
#
#                                    track_uri     tid
# 0       spotify:track:6cb0HzFQPN4BGADOmSzPCw       0
# 1       spotify:track:0HBvwy7XVhrkQljkCONgsq       1
# 2       spotify:track:5ChkMS8OtdzJeqyybCc9R5       2
# 3       spotify:track:6L89mwZXSOwYl76YXfX13s       3
# 4       spotify:track:1jNOi6m3Hn8nLEeHCp5Msr       4
# ...                                      ...     ...
# 110711  spotify:track:3p5vcN5Q9JawdzBbh5ceVr  110711
# 110712  spotify:track:2PBTwMH2mzfLigdMyPzOcp  110712
# 110713  spotify:track:5JugcqxQihVYdvCSPzmP1H  110713
# 110714  spotify:track:1cKRBp7hrBVD4eP3W9x2AI  110714
# 110715  spotify:track:38griAVM808crjbFp9gcPD  110715
#
# [110716 rows x 9 columns]

# %%
pd.read_csv('df_data/df_tracks_spark/part-00000-2ebb2f34-fa55-4871-8b78-d8d172f72b0d-c000.csv', on_bad_lines='skip')
# Out:
#                                 track_uri1  \
# 0     spotify:track:7tIJDktakabGoHjwTTa35W
# 1     spotify:track:3wKt77fHCmjWRXkmkYTxrl
# 2     spotify:track:4wBzcbZPAkMC6gpKsr84a9
# 3     spotify:track:3jS7bB0oXVOwGFZn3aE5NV
# 4     spotify:track:1J2TJKwwiNqrqAywQMBFNu
# ...                                    ...
# 9496  spotify:track:7veYmTIhhDuVIpCW6UeoxJ
# 9497  spotify:track:7gszEHRkBhgWxz4ehSe0lr
# 9498  spotify:track:7j61qfTooymeOCTrQbmoMU
# 9499  spotify:track:0mf7oWY87iDpJpEElcUzFJ
# 9500  spotify:track:11qihJCPbu6ibYpHuVMT9F
#
#                                 album_name  \
# 0                                  Take Me
# 1                        Out of the Shadow
# 2                                    Lover
# 3          Jagged Little Pill (Remastered)
# 4                                  Origami
# ...                                    ...
# 9496                              Location
# 9497  Lady and the Tramp (1955 Film Score)
# 9498                     Cooleyhighharmony
# 9499                    Rubbish/Push It Up
# 9500                      Even in the Dark
#
#                                  album_uri  \
# 0     spotify:album:7Cr3sCsROrVfclDb7d9z5z
# 1     spotify:album:6HqU5Tckb8sF6Gj2CRPla2
# 2     spotify:album:4e35UuRLPKEMnd2UJedbx1
# 3     spotify:album:5Ap3F8CxjjsQKZGASDcHNA
# 4     spotify:album:6lJWG2Z0Tw7tc9Jwf5rbTu
# ...                                    ...
# 9496  spotify:album:5XpjnV9EuzkH60PtpwHn1E
# 9497  spotify:album:2bDCjSVK1wjEaPT5YpgtyR
# 9498  spotify:album:3jknvlUSe6D9Oyn2E3JBLO
# 9499  spotify:album:0TTnmD67eV4VAL41K74gFW
# 9500  spotify:album:4QxWvw355QcDabI2Fv1MM0
#
#                                             artist_name  \
# 0                                                  Miso
# 1                                            Rogue Wave
# 2                                          George Maple
# 3                                     Alanis Morissette
# 4                                         Vinyl Theatre
# ...                                                 ...
# 9496                                             Khalid
# 9497  Peggy Lee (performer), Oliver Wallace (comduct...
# 9498                                        Boyz II Men
# 9499                                              Clipz
# 9500                                           Killmod3
#
#                                  artist_uri  duration_ms  \
# 0     spotify:artist:1ukccHTdm6Xjmag0QLNJBx       257647
# 1     spotify:artist:2JSc53B5cQ31m0xTB7JFpG       260000
# 2     spotify:artist:19m3oZKjGSLzVW0OGIAcNg       220893
# 3     spotify:artist:6ogn9necmbUdCppmNnGOdi       249493
# 4     spotify:artist:7xSEWLsywYbocdtt3xsQsU       247653
# ...                                     ...          ...
# 9496  spotify:artist:6LuN9FCkKOj5PcnpouEgny       245045
# 9497  spotify:artist:3MHlIt9IAlysdZJz2xvkj6       157126
# 9498  spotify:artist:6O74knDqdv3XaWtkII7Xjp       203440
# 9499  spotify:artist:0XX7H57SCtPTrFytCQ03go       304000
# 9500  spotify:artist:5Y4BWMNhI4DPr7qnL5f4hf       312990
#
#                                              track_name  \
# 0                                               Take Me
# 1                                               Endgame
# 2                                                  Hero
# 3                     You Oughta Know - 2015 Remastered
# 4                                              My Fault
# ...                                                 ...
# 9496                                           Location
# 9497  The Siamese Cat Song / What's Going On Down There
# 9498                                   This Is My Heart
# 9499                                            Rubbish
# 9500                                   Even in the Dark
#
#                                  track_uri  tid
# 0     spotify:track:7tIJDktakabGoHjwTTa35W  NaN
# 1     spotify:track:3wKt77fHCmjWRXkmkYTxrl  NaN
# 2     spotify:track:4wBzcbZPAkMC6gpKsr84a9  NaN
# 3     spotify:track:3jS7bB0oXVOwGFZn3aE5NV  NaN
# 4     spotify:track:1J2TJKwwiNqrqAywQMBFNu  NaN
# ...                                    ...  ...
# 9496  spotify:track:7veYmTIhhDuVIpCW6UeoxJ  NaN
# 9497  spotify:track:7gszEHRkBhgWxz4ehSe0lr  NaN
# 9498  spotify:track:7j61qfTooymeOCTrQbmoMU  NaN
# 9499  spotify:track:0mf7oWY87iDpJpEElcUzFJ  NaN
# 9500  spotify:track:11qihJCPbu6ibYpHuVMT9F  NaN
#
# [9501 rows x 9 columns]

# %%
dfp = pd.read_csv('df_data/df_playlists.csv')
dfp
# Out:
#         Unnamed: 0   pid    tid  pos
# 0                0  2000      0    0
# 1                1  2000      1    1
# 2                2  2000      2    2
# 3                3  2000      3    3
# 4                4  2000      4    4
# ...            ...   ...    ...  ...
# 199869      199869  1999   8005   11
# 199870      199870  1999  76505   12
# 199871      199871  1999  43579   13
# 199872      199872  1999  31250   14
# 199873      199873  1999  76506   15
#
# [199874 rows x 4 columns]

# %%
pd.read_csv('df_data/df_playlists_test_spark/part-00000-57743597-332c-4982-8345-33f8eb65f346-c000.csv', on_bad_lines='skip')
# Out:
#                                   track_uri      pid  pos  \
# 0      spotify:track:005X0FmdtkM1kiutosXLTR  1026437   18
# 1      spotify:track:006r3Kh3rjAW6WgkSPTMzC  1049210   66
# 2      spotify:track:00BnfL75e8vHSGCmwUWbEk  1009820    0
# 3      spotify:track:00BnfL75e8vHSGCmwUWbEk  1028810   37
# 4      spotify:track:00BnfL75e8vHSGCmwUWbEk  1042866   37
# ...                                     ...      ...  ...
# 33702  spotify:track:7zsw78LtXUD7JfEwH64HK2  1029262   78
# 33703  spotify:track:7zsw78LtXUD7JfEwH64HK2  1034047   18
# 33704  spotify:track:7zv8Fey2BaVJe0PomkkA16  1012496    5
# 33705  spotify:track:7zv8Fey2BaVJe0PomkkA16  1000178    5
# 33706  spotify:track:7zv8Fey2BaVJe0PomkkA16  1041839  130
#
#                                  track_uri1  \
# 0      spotify:track:005X0FmdtkM1kiutosXLTR
# 1                                       NaN
# 2      spotify:track:00BnfL75e8vHSGCmwUWbEk
# 3      spotify:track:00BnfL75e8vHSGCmwUWbEk
# 4      spotify:track:00BnfL75e8vHSGCmwUWbEk
# ...                                     ...
# 33702  spotify:track:7zsw78LtXUD7JfEwH64HK2
# 33703  spotify:track:7zsw78LtXUD7JfEwH64HK2
# 33704                                   NaN
# 33705                                   NaN
# 33706                                   NaN
#
#                                 album_name  \
# 0      I Hear A Symphony: Expanded Edition
# 1                                      NaN
# 2                                    Diego
# 3                                    Diego
# 4                                    Diego
# ...                                    ...
# 33702                       Little Mermaid
# 33703                       Little Mermaid
# 33704                                  NaN
# 33705                                  NaN
# 33706                                  NaN
#
#                                   album_uri   artist_name  \
# 0      spotify:album:5K23ycKA0TKPspiOf9xf7X  The Supremes
# 1                                       NaN           NaN
# 2      spotify:album:7FbbHGEqovOBqxZBsbxFqX    Tory Lanez
# 3      spotify:album:7FbbHGEqovOBqxZBsbxFqX    Tory Lanez
# 4      spotify:album:7FbbHGEqovOBqxZBsbxFqX    Tory Lanez
# ...                                     ...           ...
# 33702  spotify:album:4aAwvCRNJIqiUGVEjieWv6   Pat Carroll
# 33703  spotify:album:4aAwvCRNJIqiUGVEjieWv6   Pat Carroll
# 33704                                   NaN           NaN
# 33705                                   NaN           NaN
# 33706                                   NaN           NaN
#
#                                   artist_uri  duration_ms  \
# 0      spotify:artist:57bUPid8xztkieZfS7OlEV     164346.0
# 1                                        NaN          NaN
# 2      spotify:artist:2jku7tDXc6XoB6MO2hFuqg     242346.0
# 3      spotify:artist:2jku7tDXc6XoB6MO2hFuqg     242346.0
# 4      spotify:artist:2jku7tDXc6XoB6MO2hFuqg     242346.0
# ...                                      ...          ...
# 33702  spotify:artist:0Yy9u86cq66Se2pB9fYaiW     291693.0
# 33703  spotify:artist:0Yy9u86cq66Se2pB9fYaiW     291693.0
# 33704                                    NaN          NaN
# 33705                                    NaN          NaN
# 33706                                    NaN          NaN
#
#                                               track_name  tid
# 0                       I Hear A Symphony - Mono Version  NaN
# 1                                                    NaN  NaN
# 2                                                  Diego  NaN
# 3                                                  Diego  NaN
# 4                                                  Diego  NaN
# ...                                                  ...  ...
# 33702  Poor Unfortunate Souls - From \The Little Merm...  NaN
# 33703  Poor Unfortunate Souls - From \The Little Merm...  NaN
# 33704                                                NaN  NaN
# 33705                                                NaN  NaN
# 33706                                                NaN  NaN
#
# [33707 rows x 11 columns]

# %%
dfpi = pd.read_csv('df_data/df_playlists_info.csv')

dfpi
# Out:
#       Unnamed: 0  collaborative  duration_ms  modified_at         name  \
# 0              0          False     39413578   1446854400  party party
# 1              1          False      2386978   1495584000       summer
# 2              2          False     47356150   1509235200          Rap
# 3              3          False      6630645   1477785600          #tb
# 4              4          False      3716605   1500940800       Disney
# ...          ...            ...          ...          ...          ...
# 2995        2995          False     29183178   1509062400          woo
# 2996        2996          False      9354755   1420070400   NEW YEARS
# 2997        2997          False     10940019   1508371200        JESUS
# 2998        2998          False      7260645   1448236800          yep
# 2999        2999          False      3701742   1464307200   Sad Music
#
#       num_albums  num_artists  num_edits  num_followers  num_tracks   pid
# 0            142          116          3              1         152  2000
# 1             10            9          4              1          11  2001
# 2            128           84         65              4         221  2002
# 3             33           26          7              1          35  2003
# 4             19           19          3              1          20  2004
# ...          ...          ...        ...            ...         ...   ...
# 2995          68           24         13              2         146  1995
# 2996          37           34          3              1          38  1996
# 2997          28           22          8              2          40  1997
# 2998          27           20          3              1          29  1998
# 2999          14           12          3              1          16  1999
#
# [3000 rows x 11 columns]

# %%
dfpt = pd.read_csv('df_data/df_playlists_test.csv')
dfpt
# Out:
#         Unnamed: 0      pid     tid  pos
# 0                0  1000000   76507    0
# 1                1  1000000   18548    1
# 2                2  1000000   20986    2
# 3                3  1000000   52862    3
# 4                4  1000000    3800    4
# ...            ...      ...     ...  ...
# 280995      280995  1006767  110715    0
# 280996      280996  1006771    4337    0
# 280997      280997  1006773   38222    0
# 280998      280998  1006775   12960    0
# 280999      280999  1006778    5080    0
#
# [281000 rows x 4 columns]

# %%
dfpti = pd.read_csv('df_data/df_playlists_test_info.csv')
dfpti
# Out:
#       Unnamed: 0              name  num_holdouts  num_samples  num_tracks  \
# 0              0  spanish playlist            11            0          11
# 1              1           Groovin            48            0          48
# 2              2            uplift            40            0          40
# 3              3              WUBZ            27            0          27
# 4              4               new            41            0          41
# ...          ...               ...           ...          ...         ...
# 9995        9995     Playlist 2015            20            1          21
# 9996        9996           Workout            24            1          25
# 9997        9997             Girlz            16            1          17
# 9998        9998    let's get lost            35            1          36
# 9999        9999              Mama            28            1          29
#
#           pid
# 0     1000002
# 1     1000003
# 2     1000004
# 3     1000006
# 4     1000007
# ...       ...
# 9995  1006767
# 9996  1006771
# 9997  1006773
# 9998  1006775
# 9999  1006778
#
# [10000 rows x 6 columns]

# %% [markdown]
# ### pyspark

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import explode, col, lit, monotonically_increasing_id
from pyspark.sql.functions import broadcast

def create_spark_dataframes(data_path, challenge_file, output_path, partitions):
    """
    Process playlist and track data using Spark, and save the output as CSV files.

    Args:
        data_path (str): Path to the directory containing JSON files.
        challenge_file (str): Path to the challenge_set.json file.
        output_path (str): Path to save the resulting CSV files.

    Returns:
        None
    """

     # Initialize SparkSession with parallelism configurations
    spark = SparkSession.builder \
        .appName("Create Spark DataFrames for Playlist Dataset") \
        .config("spark.sql.shuffle.partitions", str(partitions)) \
        .config("spark.executor.memory", "4g") \
        .config("spark.executor.cores", "4") \
        .config("spark.driver.memory", "4g") \
        .getOrCreate()
    
    
    # Define column sets
    playlist_col = ['collaborative', 'duration_ms', 'modified_at', 
                    'name', 'num_albums', 'num_artists', 'num_edits',
                    'num_followers', 'num_tracks', 'pid']
    tracks_col = ['album_name', 'album_uri', 'artist_name', 'artist_uri', 
                  'duration_ms', 'track_name', 'track_uri'] 
    playlist_test_col = ['name', 'num_holdouts', 'num_samples', 'num_tracks', 'pid']

    # Read all JSON files in the directory
    df_raw = spark.read.option("multiline", "true").json(f"{data_path}/*.json").repartition(partitions)

    # Extract playlist data
    df_playlists = df_raw.select(explode(col("playlists")).alias("playlist"))

    # Extract playlist-level information
    df_playlists_info = df_playlists.select(*[col(f"playlist.{cols}").alias(cols) for cols in playlist_col])

    # Extract track-level information
    df_tracks = df_playlists.select(
        col("playlist.pid").alias("pid"),
        explode(col("playlist.tracks")).alias("track")
    ).select(
        col("track.track_uri").alias("track_uri1"),
        *[col(f"track.{cols}").alias(cols) for cols in tracks_col]
    ).drop_duplicates()

    
    
    # Add unique track ID (tid) in parallel
    df_tracks = df_tracks.withColumn("tid", monotonically_increasing_id())

    # Join playlist and track information to create a relationship DataFrame
    df_playlists_tracks = df_playlists.select(
        col("playlist.pid").alias("pid"),
        explode(col("playlist.tracks")).alias("track")
    ).select(
        col("pid"),
        col("track.track_uri").alias("track_uri"),
        col("track.pos").alias("pos")
    )
    
    df_playlists_tracks = df_playlists_tracks.join(broadcast(df_tracks), on="track_uri", how="left")
    
    # Join with track ID (tid)
#     df_playlists_tracks = df_playlists_tracks.join(df_tracks, on="track_uri", how="left")

    # Process challenge set
    df_challenge_raw = spark.read.option("multiline", "true").json(challenge_file).repartition(partitions)
    df_playlists_test_info = df_challenge_raw.select(
        explode(col("playlists")).alias("playlist")
    ).select(*[col(f"playlist.{cols}").alias(cols) for cols in playlist_test_col])

    df_playlists_test = df_challenge_raw.select(
        explode(col("playlists")).alias("playlist")
    ).select(
        col("playlist.pid").alias("pid"),
        explode(col("playlist.tracks")).alias("track")
    ).select(
        col("pid"),
        col("track.track_uri").alias("track_uri"),
        col("track.pos").alias("pos")
    ).join(broadcast(df_tracks), on="track_uri", how="left")

    # Save DataFrames as CSV files
    df_playlists_info.write.csv(f"{output_path}/df_playlists_info_spark", header=True, mode="overwrite")
    df_tracks.write.csv(f"{output_path}/df_tracks_spark", header=True, mode="overwrite")
    df_playlists_tracks.write.csv(f"{output_path}/df_playlists_spark", header=True, mode="overwrite")
    df_playlists_test_info.write.csv(f"{output_path}/df_playlists_test_info_spark", header=True, mode="overwrite")
    df_playlists_test.write.csv(f"{output_path}/df_playlists_test_spark", header=True, mode="overwrite")

    print("DataFrames successfully created and saved as CSV files.")

# %%
if __name__ == "__main__":
    # Define paths
    data_path = "data"  # Path to directory with JSON files
    challenge_file = "challenge_set.json"  # Challenge set file
    output_path = "df_data"  # Output directory for CSV files
     # Number of partitions for parallelism
    num_partitions = 200  # Adjust based on your system's resources

    # Run the function
    create_spark_dataframes(data_path, challenge_file, output_path, partitions=num_partitions)

    # Run the function
#     create_spark_dataframes(data_path, challenge_file, output_path)
# Out:
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 24/12/05 02:00:03 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# DataFrames successfully created and saved as CSV files.
# [Stage 31:=====================================================>(199 + 1) / 200]

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import explode, col, lit, monotonically_increasing_id

def create_spark_dataframes_parallel(data_path, challenge_file, output_path, partitions=200):
    """
    Process playlist and track data using Spark with parallelism, and save the output as CSV files.

    Args:
        data_path (str): Path to the directory containing JSON files.
        challenge_file (str): Path to the challenge_set.json file.
        output_path (str): Path to save the resulting CSV files.
        partitions (int): Number of partitions for parallelism. Default is 200.

    Returns:
        None
    """
    # Initialize SparkSession with parallelism configurations
    spark = SparkSession.builder \
        .appName("Create Spark DataFrames with Parallelism") \
        .config("spark.sql.shuffle.partitions", str(partitions)) \
        .config("spark.executor.memory", "4g") \
        .config("spark.executor.cores", "4") \
        .config("spark.driver.memory", "4g") \
        .getOrCreate()

    # Define column sets
    playlist_col = ['collaborative', 'duration_ms', 'modified_at', 
                    'name', 'num_albums', 'num_artists', 'num_edits',
                    'num_followers', 'num_tracks', 'pid']
    tracks_col = ['album_name', 'album_uri', 'artist_name', 'artist_uri', 
                  'duration_ms', 'track_name', 'track_uri'] 
    playlist_test_col = ['name', 'num_holdouts', 'num_samples', 'num_tracks', 'pid']

    # Read all JSON files in the directory with parallelism
    print(f"Reading files from: {data_path}")
    df_raw = spark.read.json(f"{data_path}/*.json").repartition(partitions)

    # Explode playlists to flatten the structure
    df_playlists = df_raw.select(explode(col("playlists")).alias("playlist"))

    # Extract playlist-level information
    df_playlists_info = df_playlists.select(*[col(f"playlist.{col}").alias(col) for col in playlist_col])

    # Extract track-level information
    df_tracks = df_playlists.select(
        col("playlist.pid").alias("pid"),
        explode(col("playlist.tracks")).alias("track")
    ).select(
        col("track.track_uri").alias("track_uri"),
        *[col(f"track.{col}").alias(col) for col in tracks_col]
    ).drop_duplicates()

    # Add unique track ID (tid) in parallel
    df_tracks = df_tracks.withColumn("tid", monotonically_increasing_id())

    # Join playlist and track information to create a relationship DataFrame
    df_playlists_tracks = df_playlists.select(
        col("playlist.pid").alias("pid"),
        explode(col("playlist.tracks")).alias("track")
    ).select(
        col("pid"),
        col("track.track_uri").alias("track_uri"),
        col("track.pos").alias("pos")
    )

    # Broadcast smaller DataFrame (df_tracks) for efficient join
    from pyspark.sql.functions import broadcast
    df_playlists_tracks = df_playlists_tracks.join(broadcast(df_tracks), on="track_uri", how="left")

    # Process challenge set with parallelism
    df_challenge_raw = spark.read.json(challenge_file).repartition(partitions)
    df_playlists_test_info = df_challenge_raw.select(
        explode(col("playlists")).alias("playlist")
    ).select(*[col(f"playlist.{col}").alias(col) for col in playlist_test_col])

    df_playlists_test = df_challenge_raw.select(
        explode(col("playlists")).alias("playlist")
    ).select(
        col("playlist.pid").alias("pid"),
        explode(col("playlist.tracks")).alias("track")
    ).select(
        col("pid"),
        col("track.track_uri").alias("track_uri"),
        col("track.pos").alias("pos")
    ).join(broadcast(df_tracks), on="track_uri", how="left")

    # Save DataFrames as CSV files in parallel
    print(f"Saving DataFrames to {output_path} with parallelism...")
    df_playlists_info.write.csv(f"{output_path}/df_playlists_info.csv", header=True, mode="overwrite")
    df_tracks.write.csv(f"{output_path}/df_tracks.csv", header=True, mode="overwrite")
    df_playlists_tracks.write.csv(f"{output_path}/df_playlists.csv", header=True, mode="overwrite")
    df_playlists_test_info.write.csv(f"{output_path}/df_playlists_test_info.csv", header=True, mode="overwrite")
    df_playlists_test.write.csv(f"{output_path}/df_playlists_test.csv", header=True, mode="overwrite")

    print("DataFrames successfully created and saved as CSV files with parallelism.")

if __name__ == "__main__":
    # Define paths
    data_path = "data"  # Path to directory with JSON files
    challenge_file = "challenge_set.json"  # Challenge set file
    output_path = "df_data"  # Output directory for CSV files

    # Number of partitions for parallelism
    num_partitions = 200  # Adjust based on your system's resources

    # Run the function
    create_spark_dataframes_parallel(data_path, challenge_file, output_path, partitions=num_partitions)
